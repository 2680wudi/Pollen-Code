# %% [markdown]
# 验证PyTorch安装：

# %%
import torch
print(f"PyTorch版本: {torch.__version__}")
print(f"CUDA可用性: {torch.cuda.is_available()}")
print(f"CUDA版本: {torch.version.cuda}")
# Out:
# PyTorch版本: 2.6.0+cu124
# CUDA可用性: True
# CUDA版本: 12.4

# %% [markdown]
# 安装detectron2

# %%
# !pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-vilqavqs
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-vilqavqs
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 18f69583391e5040043ca4f4bebd2c60f0ebfde0
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.10.0)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.0.10)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.1.0)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.1.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (4.67.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.18.0)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Downloading iopath-0.1.9-py3-none-any.whl.metadata (370 bytes)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.3.0)
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting black (from detectron2==0.6)
#   Downloading black-25.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (25.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (2.0.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.1->detectron2==0.6) (4.9.3)
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (8.2.1)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2==0.6)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (4.3.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (2.9.0.post0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.73.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (3.8.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (3.0.2)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 10.5 MB/s eta 0:00:00
# Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading black-25.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 57.0 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: detectron2, fvcore
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp311-cp311-linux_x86_64.whl size=6434831 sha256=177313c14c0cf5ff2e3ed35afbc30a3e7c40098225ac3c4d410916d4dc1b5a6b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mj4bqn3h/wheels/17/d9/40/60db98e485aa9455d653e29d1046601ce96fe23647f60c1c5a
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=424f897df6915ae2e43a28e0dc1de957ee431b8956782a477977de8a6845354b
#   Stored in directory: /root/.cache/pip/wheels/65/71/95/3b8fde5c65c6e4a806e0867c1651dcc71a1cb2f3430e8f355f
# Successfully built detectron2 fvcore
# Installing collected packages: yacs, portalocker, pathspec, mypy-extensions, iopath, hydra-core, black, fvcore, detectron2
# Successfully installed black-25.1.0 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.1.0 pathspec-0.12.1 portalocker-3.2.0 yacs-0.1.8

# %% [markdown]
# 验证detectron2

# %%
from detectron2 import __version__
print(f"Detectron2版本: {__version__}")
# Out:
# Detectron2版本: 0.6

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Grayscale

# %%
# =============================================================================
# Grayscale and overwrite the original file
# =============================================================================
import os
import cv2

root = "/content/drive/MyDrive/my_dataset"
species_dirs = [
    os.path.join(root, "Acer_tiles_downsampled_512"),
    os.path.join(root, "Betula_tiles_downsampled_512"),
    os.path.join(root, "Ulmaceae_tiles_downsampled_512"),
]

for species_dir in species_dirs:
    if not os.path.isdir(species_dir):
        print(f"Warning: Directory does not exist：{species_dir}")
        continue

    for fname in os.listdir(species_dir):
        if not fname.lower().endswith(".png"):
            continue
        fpath = os.path.join(species_dir, fname)
        img = cv2.imread(fpath)   # Color map
        if img is None:
            print(f"Warning: Unable to read {fpath}")
            continue
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        gray3c = cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)   # Three grayscale channels

        cv2.imwrite(fpath, gray3c)
    print(f"All PNG files in {species_dir} have been grayscaled.")
# Out:
# All PNG files in /content/drive/MyDrive/my_dataset/Acer_tiles_downsampled_512 have been grayscaled.
# All PNG files in /content/drive/MyDrive/my_dataset/Betula_tiles_downsampled_512 have been grayscaled.
# All PNG files in /content/drive/MyDrive/my_dataset/Ulmaceae_tiles_downsampled_512 have been grayscaled.

# %% [markdown]
# # Segmentatiaon model

# %% [markdown]
# 合并train and val jason files

# %%
# Convert the files
import json, os, cv2, itertools, datetime, re

entries = [
    # (VIA json, image folder, class name, split)
    ("/content/drive/MyDrive/my_dataset/Acer/train/Acer34_train.json",
     "/content/drive/MyDrive/my_dataset/Acer_tiles_downsampled_512", "Acer", "train"),
    ("/content/drive/MyDrive/my_dataset/Acer/val/Acer06_val.json",
     "/content/drive/MyDrive/my_dataset/Acer_tiles_downsampled_512", "Acer", "val"),
    ("/content/drive/MyDrive/my_dataset/Acer/test/Acer06_test.json",
     "/content/drive/MyDrive/my_dataset/Acer_tiles_downsampled_512", "Acer", "test"),

    ("/content/drive/MyDrive/my_dataset/Betula/train/Betula20_train.json",
     "/content/drive/MyDrive/my_dataset/Betula_tiles_downsampled_512", "Betula", "train"),
    ("/content/drive/MyDrive/my_dataset/Betula/val/Betula03_val.json",
     "/content/drive/MyDrive/my_dataset/Betula_tiles_downsampled_512", "Betula", "val"),
    ("/content/drive/MyDrive/my_dataset/Betula/test/Betula03_test.json",
     "/content/drive/MyDrive/my_dataset/Betula_tiles_downsampled_512", "Betula", "test"),

    ("/content/drive/MyDrive/my_dataset/Ulmaceae/train/Ulmaceae20_train.json",
     "/content/drive/MyDrive/my_dataset/Ulmaceae_tiles_downsampled_512", "Ulmaceae", "train"),
    ("/content/drive/MyDrive/my_dataset/Ulmaceae/val/Ulmaceae05_val.json",
     "/content/drive/MyDrive/my_dataset/Ulmaceae_tiles_downsampled_512", "Ulmaceae", "val"),
    ("/content/drive/MyDrive/my_dataset/Ulmaceae/test/Ulmaceae05_test.json",
     "/content/drive/MyDrive/my_dataset/Ulmaceae_tiles_downsampled_512", "Ulmaceae", "test"),
]

OUT_TRAIN = "/content/drive/MyDrive/my_dataset/Pollen/train/pollen_train_coco.json"
OUT_VAL   = "/content/drive/MyDrive/my_dataset/Pollen/val/pollen_val_coco.json"
OUT_TEST   = "/content/drive/MyDrive/my_dataset/Pollen/test/pollen_test_coco.json"
os.makedirs(os.path.dirname(OUT_TRAIN), exist_ok=True)
os.makedirs(os.path.dirname(OUT_VAL),   exist_ok=True)
os.makedirs(os.path.dirname(OUT_TEST),   exist_ok=True)

img_id, ann_id = 1, 1
name2cid = {}
coco_train = {"images": [], "annotations": []}
coco_val   = {"images": [], "annotations": []}
coco_test  = {"images": [], "annotations": []}

def safe_filename(entry, outer_key):
    if entry.get("filename"):
        return entry["filename"]
    m = re.match(r"(.+?)#\d+$", outer_key)
    if m:
        return os.path.basename(m.group(1))
    raise KeyError(f"cannot resolve filename for key {outer_key}")

def add_via(via_json, img_root, cls_name, target_dict):
    global img_id, ann_id, name2cid

    via = json.load(open(via_json))
    items = (via["_via_img_metadata"].items()
             if isinstance(via, dict) and "_via_img_metadata" in via
             else via.items()) if isinstance(via, dict) else enumerate(via)

    cid = name2cid.setdefault(cls_name, len(name2cid) + 1)

    for outer_key, ent in items:
        fname = safe_filename(ent, outer_key)
        fpath = os.path.join(img_root, fname)
        if not os.path.exists(fpath):
            raise FileNotFoundError(f"{fpath} not found")

        h, w = cv2.imread(fpath).shape[:2]
        rel_path = os.path.relpath(fpath, "/content/drive/MyDrive/my_dataset")

        target_dict["images"].append({
            "id": img_id,
            "file_name": rel_path,
            "height": h,
            "width":  w
        })

        for reg in ent["regions"]:
            xs, ys = reg["shape_attributes"]["all_points_x"], reg["shape_attributes"]["all_points_y"]
            x0, y0 = min(xs), min(ys)
            bw, bh = max(xs) - x0, max(ys) - y0
            poly   = list(itertools.chain.from_iterable(zip(xs, ys)))
            target_dict["annotations"].append({
                "id": ann_id,
                "image_id": img_id,
                "category_id": cid,
                "bbox": [x0, y0, bw, bh],
                "area": bw * bh,
                "segmentation": [poly],
                "iscrowd": 0
            })
            ann_id += 1
        img_id += 1

for via_json, img_dir, cls, split in entries:
    target = {"train": coco_train, "val": coco_val, "test": coco_test}[split]
    add_via(via_json, img_dir, cls, target)

def finalize(coco_obj):
    coco_obj["info"] = {"description": "Merged pollen dataset",
                        "year": datetime.datetime.now().year}
    coco_obj["licenses"] = []
    coco_obj["categories"] = [{"id": cid, "name": name, "supercategory": "pollen"}
                              for name, cid in name2cid.items()]

for c in (coco_train, coco_val, coco_test): finalize(c)

finalize(coco_train)
finalize(coco_val)

json.dump(coco_train, open(OUT_TRAIN, "w"))
json.dump(coco_val,   open(OUT_VAL,   "w"))
json.dump(coco_test,  open(OUT_TEST,  "w"))
print(f"train : {len(coco_train['images'])} images | {len(coco_train['annotations'])} anns")
print(f"val   : {len(coco_val['images'])} images | {len(coco_val['annotations'])} anns")
print(f"test  : {len(coco_test['images'])} images | {len(coco_test['annotations'])} anns")

# Register the merged COCO to detectron2
from detectron2.data.datasets import register_coco_instances

root = "/content/drive/MyDrive/my_dataset"
register_coco_instances("pollen_train", {}, OUT_TRAIN, root)
register_coco_instances("pollen_val",   {}, OUT_VAL,   root)
register_coco_instances("pollen_test",  {}, OUT_TEST,  root)
# Out:
# train : 74 images | 2489 anns
# val   : 14 images | 493 anns
# test  : 14 images | 480 anns

# %% [markdown]
# To verify the dataset is in correct format.

# %%
import random, os, cv2, sys
from detectron2.data import DatasetCatalog, MetadataCatalog
from detectron2.utils.visualizer import Visualizer
from google.colab.patches import cv2_imshow

# dataset name registered earlier
ds_name   = "pollen_train"
image_root = "/content/drive/MyDrive/my_dataset"   # same root used in register_coco_instances

dataset_dicts = DatasetCatalog.get(ds_name)
meta          = MetadataCatalog.get(ds_name)

for d in random.sample(dataset_dicts, 3):
    # build absolute path if file_name is relative
    img_path = d["file_name"]
    if not os.path.isabs(img_path):
        img_path = os.path.join(image_root, img_path)

    img = cv2.imread(img_path)
    if img is None:
        print(f"[WARN] cannot read {img_path}", file=sys.stderr)
        continue

    vis = Visualizer(img[:, :, ::-1], metadata=meta, scale=0.5)
    vis_img = vis.draw_dataset_dict(d).get_image()
    cv2_imshow(vis_img[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# Train Mask R-CNN on the merged pollen dataset (3 classes) 2025.6.10

# %%
import os
import torch
from detectron2.engine import DefaultTrainer, hooks
from detectron2.config import get_cfg
from detectron2 import model_zoo
from detectron2.evaluation import COCOEvaluator
from detectron2.data import build_detection_test_loader, DatasetMapper
from detectron2.data import DatasetMapper, get_detection_dataset_dicts, MapDataset
from detectron2.data.samplers import InferenceSampler
from torch.utils.data import DataLoader


# Custom validation loss hook
class LossEvalHook(hooks.HookBase):
    def __init__(self, eval_period, model, data_loader):
        self._period = eval_period
        self._model = model
        self._data_loader = data_loader

    def after_step(self):
        if self.trainer.iter % self._period == 0:
            print(f"[hook] Running validation loss at iteration {self.trainer.iter}")
            self._model.train()
            with torch.no_grad():
              losses = []
              for batch in self._data_loader:
                  print(f"[hook] got batch of size: {len(batch)}")
                  batch = [x for x in batch if "instances" in x and len(x["instances"]) > 0]
                  if not batch:
                      print("[hook] skipped empty batch (no instances)")
                      continue
                  try:
                      loss_dict = self._model(batch)
                      total_loss = sum(loss_dict.values()).item()
                      print(f"[hook] total_loss = {total_loss:.4f}")
                      losses.append(total_loss)
                  except Exception as e:
                      print(f"[hook] Skipped batch due to error: {e}")

              if losses:
                  avg_loss = sum(losses) / len(losses)
                  print(f"[hook] avg validation loss = {avg_loss:.4f}")
                  self.trainer.storage.put_scalar("validation_total_loss", avg_loss)
              else:
                  print("[hook] No valid losses to average.")
            self._model.train()

def trivial_batch_collator(batch):
    return batch

def build_val_loader(cfg, batch_size=4):
    dataset_dicts = get_detection_dataset_dicts([cfg.DATASETS.TEST[0]])
    mapper = DatasetMapper(cfg, is_train=True)
    dataset = MapDataset(dataset_dicts, mapper)
    sampler = InferenceSampler(len(dataset))
    return DataLoader(
        dataset,
        batch_size=batch_size,
        sampler=sampler,
        num_workers=cfg.DATALOADER.NUM_WORKERS,
        collate_fn=trivial_batch_collator
    )

# Customize Trainer and add hook
class MyTrainer(DefaultTrainer):
    def build_hooks(self):
        hooks_list = super().build_hooks()

        # Set loader with batch_size=4
        val_loader = build_val_loader(self.cfg, batch_size=4)

        hooks_list.insert(-1, LossEvalHook(self.cfg.TEST.EVAL_PERIOD, self.model, val_loader))
        return hooks_list

    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
        return COCOEvaluator(dataset_name, cfg, False, output_folder)

# Basic configuration
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))

cfg.DATASETS.TRAIN = ("pollen_train",)
cfg.DATASETS.TEST  = ("pollen_val",)

cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(
    "COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"
)

# solver (learning-rate & schedule)
cfg.SOLVER.IMS_PER_BATCH = 4   # batch-size = 4 images / iteration
cfg.SOLVER.BASE_LR = 2.5e-4   # smaller LR for small dataset
cfg.SOLVER.MAX_ITER = 3000   # raise if you need better accuracy
cfg.SOLVER.STEPS = []   # no LR decay

cfg.SOLVER.CHECKPOINT_PERIOD = 200
cfg.TEST.EVAL_PERIOD = 200

# Region of Interest (ROI) head
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 3  # Acer, Betula, Ulmaceae

# output directory
cfg.OUTPUT_DIR = "/content/drive/MyDrive/my_dataset/pollen_output"
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# start training
trainer = MyTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [07/05 15:25:36 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=12, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [07/05 15:25:36 d2.data.datasets.coco]: Loaded 74 images in COCO format from /content/drive/MyDrive/my_dataset/Pollen/train/pollen_train_coco.json
# [07/05 15:25:36 d2.data.build]: Removed 0 images with no usable annotations. 74 images left.
# [07/05 15:25:36 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |    Acer    | 648          |   Betula   | 881          |  Ulmaceae  | 960          |
# |            |              |            |              |            |              |
# |   total    | 2489         |            |              |            |              |
# [07/05 15:25:36 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [07/05 15:25:36 d2.data.build]: Using training sampler TrainingSampler
# [07/05 15:25:36 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/05 15:25:36 d2.data.common]: Serializing 74 elements to byte tensors and concatenating them all ...
# [07/05 15:25:36 d2.data.common]: Serialized dataset takes 0.40 MiB
# [07/05 15:25:36 d2.data.build]: Making batched data loader with batch_size=4
# [07/05 15:25:37 d2.data.datasets.coco]: Loaded 14 images in COCO format from /content/drive/MyDrive/my_dataset/Pollen/val/pollen_val_coco.json
# [07/05 15:25:37 d2.data.build]: Removed 0 images with no usable annotations. 14 images left.
# [07/05 15:25:37 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |    Acer    | 114          |   Betula   | 99           |  Ulmaceae  | 280          |
# |            |              |            |              |            |              |
# |   total    | 493          |            |              |            |              |
# [07/05 15:25:37 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [07/05 15:25:37 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# model_final_f10217.pkl: 178MB [00:01, 126MB/s]
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (12, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (12,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (3, 256, 1, 1) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (3,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [07/05 15:25:38 d2.engine.train_loop]: Starting training from iteration 0
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [hook] Running validation loss at iteration 0
# [hook] got batch of size: 4
# [hook] total_loss = 3.3082
# [hook] got batch of size: 4
# [hook] total_loss = 4.3058
# [hook] got batch of size: 4
# [hook] total_loss = 3.7513
# [hook] got batch of size: 2
# [hook] total_loss = 3.4861
# [hook] avg validation loss = 3.7128
# [07/05 15:25:57 d2.utils.events]:  eta: 0:35:07  iter: 19  total_loss: 3.755  loss_cls: 1.327  loss_box_reg: 0.723  loss_mask: 0.6923  loss_rpn_cls: 0.8882  loss_rpn_loc: 0.07915  validation_total_loss: 3.713    time: 0.6911  last_time: 0.7136  data_time: 0.0328  last_data_time: 0.0141   lr: 4.9953e-06  max_mem: 3096M
# [07/05 15:26:18 d2.utils.events]:  eta: 0:34:59  iter: 39  total_loss: 2.93  loss_cls: 1.219  loss_box_reg: 0.7466  loss_mask: 0.6852  loss_rpn_cls: 0.196  loss_rpn_loc: 0.07621  validation_total_loss: 3.713    time: 0.6940  last_time: 0.7371  data_time: 0.0204  last_data_time: 0.0137   lr: 9.9902e-06  max_mem: 3096M
# [07/05 15:26:32 d2.utils.events]:  eta: 0:34:45  iter: 59  total_loss: 2.598  loss_cls: 1.064  loss_box_reg: 0.7609  loss_mask: 0.6647  loss_rpn_cls: 0.05235  loss_rpn_loc: 0.0699  validation_total_loss: 3.713    time: 0.6932  last_time: 0.7451  data_time: 0.0203  last_data_time: 0.0339   lr: 1.4985e-05  max_mem: 3096M
# [07/05 15:26:46 d2.utils.events]:  eta: 0:34:35  iter: 79  total_loss: 2.4  loss_cls: 0.9057  loss_box_reg: 0.7496  loss_mask: 0.6397  loss_rpn_cls: 0.0322  loss_rpn_loc: 0.06605  validation_total_loss: 3.713    time: 0.6965  last_time: 0.7294  data_time: 0.0174  last_data_time: 0.0112   lr: 1.998e-05  max_mem: 3097M
# [07/05 15:27:00 d2.utils.events]:  eta: 0:34:28  iter: 99  total_loss: 2.253  loss_cls: 0.7802  loss_box_reg: 0.7633  loss_mask: 0.612  loss_rpn_cls: 0.02482  loss_rpn_loc: 0.06844  validation_total_loss: 3.713    time: 0.7011  last_time: 0.6013  data_time: 0.0204  last_data_time: 0.0120   lr: 2.4975e-05  max_mem: 3097M
# [07/05 15:27:15 d2.utils.events]:  eta: 0:34:23  iter: 119  total_loss: 2.125  loss_cls: 0.6987  loss_box_reg: 0.7474  loss_mask: 0.5728  loss_rpn_cls: 0.02511  loss_rpn_loc: 0.06358  validation_total_loss: 3.713    time: 0.7065  last_time: 0.6813  data_time: 0.0180  last_data_time: 0.0113   lr: 2.997e-05  max_mem: 3097M
# [07/05 15:27:29 d2.utils.events]:  eta: 0:34:02  iter: 139  total_loss: 2.047  loss_cls: 0.6583  loss_box_reg: 0.7472  loss_mask: 0.5441  loss_rpn_cls: 0.02761  loss_rpn_loc: 0.06979  validation_total_loss: 3.713    time: 0.7054  last_time: 0.6959  data_time: 0.0155  last_data_time: 0.0220   lr: 3.4965e-05  max_mem: 3097M
# [07/05 15:27:43 d2.utils.events]:  eta: 0:33:52  iter: 159  total_loss: 1.94  loss_cls: 0.6255  loss_box_reg: 0.7503  loss_mask: 0.4961  loss_rpn_cls: 0.02517  loss_rpn_loc: 0.05878  validation_total_loss: 3.713    time: 0.7070  last_time: 0.5836  data_time: 0.0176  last_data_time: 0.0121   lr: 3.996e-05  max_mem: 3097M
# [07/05 15:27:58 d2.utils.events]:  eta: 0:33:40  iter: 179  total_loss: 1.866  loss_cls: 0.5927  loss_box_reg: 0.7377  loss_mask: 0.4627  loss_rpn_cls: 0.02357  loss_rpn_loc: 0.06064  validation_total_loss: 3.713    time: 0.7099  last_time: 0.6625  data_time: 0.0203  last_data_time: 0.0215   lr: 4.4955e-05  max_mem: 3097M
# [07/05 15:28:24 d2.data.datasets.coco]: Loaded 14 images in COCO format from /content/drive/MyDrive/my_dataset/Pollen/val/pollen_val_coco.json
# [07/05 15:28:24 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [07/05 15:28:24 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/05 15:28:24 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [07/05 15:28:24 d2.data.common]: Serialized dataset takes 0.08 MiB
# WARNING [07/05 15:28:24 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [07/05 15:28:24 d2.evaluation.evaluator]: Start inference on 14 batches
# [07/05 15:28:26 d2.evaluation.evaluator]: Inference done 11/14. Dataloading: 0.0011 s/iter. Inference: 0.1012 s/iter. Eval: 0.0469 s/iter. Total: 0.1493 s/iter. ETA=0:00:00
# [07/05 15:28:27 d2.evaluation.evaluator]: Total inference time: 0:00:01.387049 (0.154117 s / iter per device, on 1 devices)
# [07/05 15:28:27 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.100810 s / iter per device, on 1 devices)
# [07/05 15:28:27 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/05 15:28:27 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/my_dataset/pollen_output/inference/coco_instances_results.json
# [07/05 15:28:28 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/05 15:28:28 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/05 15:28:28 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [07/05 15:28:28 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/05 15:28:28 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.354
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.472
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.405
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.359
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.622
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.452
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.626
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [07/05 15:28:28 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 35.396 | 47.184 | 40.516 | 20.082 | 35.941 |  nan  |
# [07/05 15:28:28 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [07/05 15:28:28 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Acer       | 42.935 | Betula     | 34.610 | Ulmaceae   | 28.642 |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [07/05 15:28:28 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [07/05 15:28:28 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [07/05 15:28:28 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/05 15:28:28 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.357
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.472
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.438
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.381
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.026
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.263
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.607
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.437
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.615
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [07/05 15:28:28 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 35.682 | 47.186 | 43.772 | 20.519 | 38.083 |  nan  |
# [07/05 15:28:28 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [07/05 15:28:28 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Acer       | 40.339 | Betula     | 38.346 | Ulmaceae   | 28.360 |
# [07/05 15:28:28 d2.engine.defaults]: Evaluation results for pollen_val in csv format:
# [07/05 15:28:28 d2.evaluation.testing]: copypaste: Task: bbox
# [07/05 15:28:28 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/05 15:28:28 d2.evaluation.testing]: copypaste: 35.3957,47.1837,40.5156,20.0823,35.9414,nan
# [07/05 15:28:28 d2.evaluation.testing]: copypaste: Task: segm
# [07/05 15:28:28 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/05 15:28:28 d2.evaluation.testing]: copypaste: 35.6819,47.1856,43.7717,20.5191,38.0829,nan
# [07/05 15:28:28 d2.utils.events]:  eta: 0:33:26  iter: 199  total_loss: 1.797  loss_cls: 0.5703  loss_box_reg: 0.7366  loss_mask: 0.4299  loss_rpn_cls: 0.01964  loss_rpn_loc: 0.06293  validation_total_loss: 3.713    time: 0.7113  last_time: 0.6790  data_time: 0.0155  last_data_time: 0.0370   lr: 4.995e-05  max_mem: 3097M
# [hook] Running validation loss at iteration 200
# [hook] got batch of size: 4
# [hook] total_loss = 1.6863
# [hook] got batch of size: 4
# [hook] total_loss = 1.7525
# [hook] got batch of size: 4
# [hook] total_loss = 1.8318
# [hook] got batch of size: 2
# [hook] total_loss = 2.1615
# [hook] avg validation loss = 1.8580
# [07/05 15:28:51 d2.utils.events]:  eta: 0:33:20  iter: 219  total_loss: 1.726  loss_cls: 0.5419  loss_box_reg: 0.7215  loss_mask: 0.3942  loss_rpn_cls: 0.02024  loss_rpn_loc: 0.05813  validation_total_loss: 1.858    time: 0.7454  last_time: 0.7192  data_time: 0.3523  last_data_time: 0.0344   lr: 5.4945e-05  max_mem: 3097M
# [07/05 15:29:05 d2.utils.events]:  eta: 0:33:05  iter: 239  total_loss: 1.646  loss_cls: 0.5075  loss_box_reg: 0.6954  loss_mask: 0.3538  loss_rpn_cls: 0.01694  loss_rpn_loc: 0.06219  validation_total_loss: 1.858    time: 0.7437  last_time: 0.7079  data_time: 0.0181  last_data_time: 0.0154   lr: 5.994e-05  max_mem: 3097M
# [07/05 15:29:20 d2.utils.events]:  eta: 0:32:48  iter: 259  total_loss: 1.603  loss_cls: 0.4781  loss_box_reg: 0.6899  loss_mask: 0.3338  loss_rpn_cls: 0.01536  loss_rpn_loc: 0.05923  validation_total_loss: 1.858    time: 0.7426  last_time: 0.6286  data_time: 0.0215  last_data_time: 0.0202   lr: 6.4935e-05  max_mem: 3097M
# [07/05 15:29:35 d2.utils.events]:  eta: 0:32:40  iter: 279  total_loss: 1.539  loss_cls: 0.475  loss_box_reg: 0.6711  loss_mask: 0.3076  loss_rpn_cls: 0.01239  loss_rpn_loc: 0.05887  validation_total_loss: 1.858    time: 0.7436  last_time: 0.7836  data_time: 0.0173  last_data_time: 0.0156   lr: 6.993e-05  max_mem: 3097M
# [07/05 15:29:52 d2.utils.events]:  eta: 0:32:39  iter: 299  total_loss: 1.5  loss_cls: 0.4422  loss_box_reg: 0.6523  loss_mask: 0.2914  loss_rpn_cls: 0.01658  loss_rpn_loc: 0.06346  validation_total_loss: 1.858    time: 0.7492  last_time: 0.7684  data_time: 0.0260  last_data_time: 0.0150   lr: 7.4925e-05  max_mem: 3097M
# [07/05 15:30:07 d2.utils.events]:  eta: 0:32:30  iter: 319  total_loss: 1.34  loss_cls: 0.4081  loss_box_reg: 0.6207  loss_mask: 0.2532  loss_rpn_cls: 0.0171  loss_rpn_loc: 0.05554  validation_total_loss: 1.858    time: 0.7494  last_time: 0.6048  data_time: 0.0215  last_data_time: 0.0139   lr: 7.992e-05  max_mem: 3097M
# [07/05 15:30:22 d2.utils.events]:  eta: 0:32:20  iter: 339  total_loss: 1.232  loss_cls: 0.3851  loss_box_reg: 0.5678  loss_mask: 0.2304  loss_rpn_cls: 0.01206  loss_rpn_loc: 0.05728  validation_total_loss: 1.858    time: 0.7503  last_time: 0.7049  data_time: 0.0211  last_data_time: 0.0214   lr: 8.4915e-05  max_mem: 3097M
# [07/05 15:30:37 d2.utils.events]:  eta: 0:32:06  iter: 359  total_loss: 1.234  loss_cls: 0.3903  loss_box_reg: 0.5545  loss_mask: 0.2141  loss_rpn_cls: 0.01276  loss_rpn_loc: 0.0604  validation_total_loss: 1.858    time: 0.7499  last_time: 0.7437  data_time: 0.0215  last_data_time: 0.0241   lr: 8.991e-05  max_mem: 3097M
# [07/05 15:30:52 d2.utils.events]:  eta: 0:31:55  iter: 379  total_loss: 1.142  loss_cls: 0.3626  loss_box_reg: 0.5031  loss_mask: 0.2028  loss_rpn_cls: 0.01152  loss_rpn_loc: 0.0598  validation_total_loss: 1.858    time: 0.7511  last_time: 0.8332  data_time: 0.0229  last_data_time: 0.0270   lr: 9.4905e-05  max_mem: 3097M
# [07/05 15:31:16 d2.data.datasets.coco]: Loaded 14 images in COCO format from /content/drive/MyDrive/my_dataset/Pollen/val/pollen_val_coco.json
# [07/05 15:31:16 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [07/05 15:31:16 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/05 15:31:17 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [07/05 15:31:17 d2.data.common]: Serialized dataset takes 0.08 MiB
# WARNING [07/05 15:31:17 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [07/05 15:31:17 d2.evaluation.evaluator]: Start inference on 14 batches
# [07/05 15:31:19 d2.evaluation.evaluator]: Inference done 11/14. Dataloading: 0.0033 s/iter. Inference: 0.1151 s/iter. Eval: 0.0801 s/iter. Total: 0.1985 s/iter. ETA=0:00:00
# [07/05 15:31:20 d2.evaluation.evaluator]: Total inference time: 0:00:01.831287 (0.203476 s / iter per device, on 1 devices)
# [07/05 15:31:20 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:01 (0.113276 s / iter per device, on 1 devices)
# [07/05 15:31:20 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/05 15:31:20 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/my_dataset/pollen_output/inference/coco_instances_results.json
# [07/05 15:31:20 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/05 15:31:20 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/05 15:31:20 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [07/05 15:31:20 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/05 15:31:20 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.02 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.586
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.728
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.409
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.568
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.260
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.745
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.622
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.769
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [07/05 15:31:20 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 58.615 | 79.964 | 72.820 | 40.919 | 56.752 |  nan  |
# [07/05 15:31:20 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [07/05 15:31:20 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Acer       | 59.914 | Betula     | 56.159 | Ulmaceae   | 59.771 |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [07/05 15:31:20 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [07/05 15:31:20 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [07/05 15:31:20 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/05 15:31:20 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.633
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.797
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.736
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.371
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.630
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.785
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.661
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.806
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [07/05 15:31:20 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 63.278 | 79.656 | 73.553 | 37.108 | 63.032 |  nan  |
# [07/05 15:31:20 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [07/05 15:31:20 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Acer       | 62.937 | Betula     | 62.785 | Ulmaceae   | 64.114 |
# [07/05 15:31:20 d2.engine.defaults]: Evaluation results for pollen_val in csv format:
# [07/05 15:31:20 d2.evaluation.testing]: copypaste: Task: bbox
# [07/05 15:31:20 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/05 15:31:20 d2.evaluation.testing]: copypaste: 58.6146,79.9642,72.8199,40.9189,56.7522,nan
# [07/05 15:31:20 d2.evaluation.testing]: copypaste: Task: segm
# [07/05 15:31:20 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/05 15:31:20 d2.evaluation.testing]: copypaste: 63.2784,79.6558,73.5527,37.1080,63.0322,nan
# [07/05 15:31:20 d2.utils.events]:  eta: 0:31:40  iter: 399  total_loss: 1.009  loss_cls: 0.3378  loss_box_reg: 0.4446  loss_mask: 0.1775  loss_rpn_cls: 0.01176  loss_rpn_loc: 0.05787  validation_total_loss: 1.858    time: 0.7503  last_time: 0.6851  data_time: 0.0185  last_data_time: 0.0122   lr: 9.99e-05  max_mem: 3097M
# [hook] Running validation loss at iteration 400
# [hook] got batch of size: 4
# [hook] total_loss = 0.7720
# [hook] got batch of size: 4
# [hook] total_loss = 0.9789
# [hook] got batch of size: 4
# [hook] total_loss = 1.2758
# [hook] got batch of size: 2
# [hook] total_loss = 1.4444
# [hook] avg validation loss = 1.1177
# [07/05 15:31:43 d2.utils.events]:  eta: 0:31:25  iter: 419  total_loss: 0.9483  loss_cls: 0.3133  loss_box_reg: 0.3791  loss_mask: 0.1638  loss_rpn_cls: 0.01161  loss_rpn_loc: 0.05204  validation_total_loss: 1.118    time: 0.7669  last_time: 0.7013  data_time: 0.3849  last_data_time: 0.0132   lr: 0.0001049  max_mem: 3097M
# [07/05 15:31:58 d2.utils.events]:  eta: 0:31:15  iter: 439  total_loss: 0.9257  loss_cls: 0.3232  loss_box_reg: 0.3663  loss_mask: 0.1656  loss_rpn_cls: 0.01028  loss_rpn_loc: 0.06028  validation_total_loss: 1.118    time: 0.7661  last_time: 0.8390  data_time: 0.0251  last_data_time: 0.0134   lr: 0.00010989  max_mem: 3097M
# [07/05 15:32:14 d2.utils.events]:  eta: 0:31:05  iter: 459  total_loss: 0.9262  loss_cls: 0.3141  loss_box_reg: 0.3454  loss_mask: 0.1652  loss_rpn_cls: 0.01389  loss_rpn_loc: 0.06092  validation_total_loss: 1.118    time: 0.7660  last_time: 0.8144  data_time: 0.0213  last_data_time: 0.0360   lr: 0.00011489  max_mem: 3097M
# [07/05 15:32:29 d2.utils.events]:  eta: 0:30:54  iter: 479  total_loss: 0.8097  loss_cls: 0.2916  loss_box_reg: 0.3039  loss_mask: 0.1524  loss_rpn_cls: 0.008792  loss_rpn_loc: 0.05826  validation_total_loss: 1.118    time: 0.7655  last_time: 0.7299  data_time: 0.0193  last_data_time: 0.0124   lr: 0.00011988  max_mem: 3097M
# [07/05 15:32:43 d2.utils.events]:  eta: 0:30:37  iter: 499  total_loss: 0.774  loss_cls: 0.2711  loss_box_reg: 0.2872  loss_mask: 0.1556  loss_rpn_cls: 0.01182  loss_rpn_loc: 0.05936  validation_total_loss: 1.118    time: 0.7641  last_time: 0.7204  data_time: 0.0191  last_data_time: 0.0363   lr: 0.00012488  max_mem: 3097M
# [07/05 15:32:59 d2.utils.events]:  eta: 0:30:24  iter: 519  total_loss: 0.7506  loss_cls: 0.2539  loss_box_reg: 0.2781  loss_mask: 0.1519  loss_rpn_cls: 0.01206  loss_rpn_loc: 0.05728  validation_total_loss: 1.118    time: 0.7638  last_time: 0.7768  data_time: 0.0177  last_data_time: 0.0124   lr: 0.00012987  max_mem: 3097M
# [07/05 15:33:13 d2.utils.events]:  eta: 0:30:08  iter: 539  total_loss: 0.678  loss_cls: 0.2283  loss_box_reg: 0.2536  loss_mask: 0.1477  loss_rpn_cls: 0.01217  loss_rpn_loc: 0.05692  validation_total_loss: 1.118    time: 0.7625  last_time: 0.6754  data_time: 0.0188  last_data_time: 0.0128   lr: 0.00013487  max_mem: 3097M
# [07/05 15:33:28 d2.utils.events]:  eta: 0:29:57  iter: 559  total_loss: 0.7206  loss_cls: 0.2345  loss_box_reg: 0.2517  loss_mask: 0.148  loss_rpn_cls: 0.01228  loss_rpn_loc: 0.05655  validation_total_loss: 1.118    time: 0.7625  last_time: 0.7260  data_time: 0.0219  last_data_time: 0.0177   lr: 0.00013986  max_mem: 3097M
# [07/05 15:33:44 d2.utils.events]:  eta: 0:29:43  iter: 579  total_loss: 0.6643  loss_cls: 0.2327  loss_box_reg: 0.2462  loss_mask: 0.1409  loss_rpn_cls: 0.008227  loss_rpn_loc: 0.05825  validation_total_loss: 1.118    time: 0.7623  last_time: 0.7902  data_time: 0.0205  last_data_time: 0.0159   lr: 0.00014486  max_mem: 3097M
# [07/05 15:34:09 d2.data.datasets.coco]: Loaded 14 images in COCO format from /content/drive/MyDrive/my_dataset/Pollen/val/pollen_val_coco.json
# [07/05 15:34:09 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [07/05 15:34:09 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/05 15:34:09 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [07/05 15:34:09 d2.data.common]: Serialized dataset takes 0.08 MiB
# WARNING [07/05 15:34:09 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [07/05 15:34:09 d2.evaluation.evaluator]: Start inference on 14 batches
# [07/05 15:34:12 d2.evaluation.evaluator]: Inference done 11/14. Dataloading: 0.0029 s/iter. Inference: 0.1001 s/iter. Eval: 0.0520 s/iter. Total: 0.1550 s/iter. ETA=0:00:00
# [07/05 15:34:13 d2.evaluation.evaluator]: Total inference time: 0:00:01.436177 (0.159575 s / iter per device, on 1 devices)
# [07/05 15:34:13 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.100107 s / iter per device, on 1 devices)
# [07/05 15:34:13 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/05 15:34:13 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/my_dataset/pollen_output/inference/coco_instances_results.json
# [07/05 15:34:13 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/05 15:34:13 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/05 15:34:13 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [07/05 15:34:13 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/05 15:34:13 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.740
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.914
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.863
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.617
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.749
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.278
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.828
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.759
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.838
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [07/05 15:34:13 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 74.023 | 91.421 | 86.276 | 61.700 | 74.916 |  nan  |
# [07/05 15:34:13 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [07/05 15:34:13 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Acer       | 69.145 | Betula     | 77.431 | Ulmaceae   | 75.492 |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [07/05 15:34:13 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [07/05 15:34:13 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [07/05 15:34:13 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/05 15:34:13 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.748
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.912
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.851
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.488
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.776
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.280
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.832
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.761
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.846
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [07/05 15:34:13 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 74.782 | 91.208 | 85.064 | 48.771 | 77.560 |  nan  |
# [07/05 15:34:13 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [07/05 15:34:13 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Acer       | 69.605 | Betula     | 80.159 | Ulmaceae   | 74.582 |
# [07/05 15:34:13 d2.engine.defaults]: Evaluation results for pollen_val in csv format:
# [07/05 15:34:13 d2.evaluation.testing]: copypaste: Task: bbox
# [07/05 15:34:13 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/05 15:34:13 d2.evaluation.testing]: copypaste: 74.0227,91.4214,86.2764,61.7004,74.9160,nan
# [07/05 15:34:13 d2.evaluation.testing]: copypaste: Task: segm
# [07/05 15:34:13 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/05 15:34:13 d2.evaluation.testing]: copypaste: 74.7822,91.2081,85.0644,48.7707,77.5598,nan
# [07/05 15:34:13 d2.utils.events]:  eta: 0:29:31  iter: 599  total_loss: 0.6976  loss_cls: 0.2144  loss_box_reg: 0.2458  loss_mask: 0.1438  loss_rpn_cls: 0.008285  loss_rpn_loc: 0.06135  validation_total_loss: 1.118    time: 0.7621  last_time: 0.6146  data_time: 0.0222  last_data_time: 0.0110   lr: 0.00014985  max_mem: 3097M
# [hook] Running validation loss at iteration 600
# [hook] got batch of size: 4
# [hook] total_loss = 0.6010
# [hook] got batch of size: 4
# [hook] total_loss = 0.7310
# [hook] got batch of size: 4
# [hook] total_loss = 0.5581
# [hook] got batch of size: 2
# [hook] total_loss = 0.9978
# [hook] avg validation loss = 0.7220
# ...
# [07/05 16:06:29 d2.data.common]: Serialized dataset takes 0.08 MiB
# WARNING [07/05 16:06:29 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [07/05 16:06:29 d2.evaluation.evaluator]: Start inference on 14 batches
# [07/05 16:06:31 d2.evaluation.evaluator]: Inference done 11/14. Dataloading: 0.0012 s/iter. Inference: 0.0886 s/iter. Eval: 0.0216 s/iter. Total: 0.1114 s/iter. ETA=0:00:00
# [07/05 16:06:31 d2.evaluation.evaluator]: Total inference time: 0:00:01.145008 (0.127223 s / iter per device, on 1 devices)
# [07/05 16:06:31 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.091130 s / iter per device, on 1 devices)
# [07/05 16:06:31 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/05 16:06:31 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/my_dataset/pollen_output/inference/coco_instances_results.json
# [07/05 16:06:31 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/05 16:06:31 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/05 16:06:31 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [07/05 16:06:31 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/05 16:06:31 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.810
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.973
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.945
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.728
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.826
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.851
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.778
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.865
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [07/05 16:06:31 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 80.959 | 97.346 | 94.455 | 72.802 | 82.630 |  nan  |
# [07/05 16:06:31 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [07/05 16:06:31 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Acer       | 79.927 | Betula     | 82.580 | Ulmaceae   | 80.371 |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [07/05 16:06:31 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [07/05 16:06:31 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [07/05 16:06:31 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/05 16:06:31 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.828
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.973
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.948
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.626
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.862
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.868
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.794
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.883
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [07/05 16:06:31 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 82.836 | 97.346 | 94.786 | 62.640 | 86.154 |  nan  |
# [07/05 16:06:31 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [07/05 16:06:31 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Acer       | 81.275 | Betula     | 85.952 | Ulmaceae   | 81.282 |
# [07/05 16:06:31 d2.engine.defaults]: Evaluation results for pollen_val in csv format:
# [07/05 16:06:31 d2.evaluation.testing]: copypaste: Task: bbox
# [07/05 16:06:31 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/05 16:06:31 d2.evaluation.testing]: copypaste: 80.9591,97.3462,94.4549,72.8017,82.6297,nan
# [07/05 16:06:31 d2.evaluation.testing]: copypaste: Task: segm
# [07/05 16:06:31 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/05 16:06:31 d2.evaluation.testing]: copypaste: 82.8363,97.3462,94.7860,62.6404,86.1543,nan
# [07/05 16:06:31 d2.utils.events]:  eta: 0:02:40  iter: 2799  total_loss: 0.3744  loss_cls: 0.0682  loss_box_reg: 0.1594  loss_mask: 0.1086  loss_rpn_cls: 0.003922  loss_rpn_loc: 0.03693  validation_total_loss: 0.5584    time: 0.8001  last_time: 0.7295  data_time: 0.0406  last_data_time: 0.0198   lr: 0.00025  max_mem: 3098M
# [hook] Running validation loss at iteration 2800
# [hook] got batch of size: 4
# [hook] total_loss = 0.5383
# [hook] got batch of size: 4
# [hook] total_loss = 0.4992
# [hook] got batch of size: 4
# [hook] total_loss = 0.4855
# [hook] got batch of size: 2
# [hook] total_loss = 0.6376
# [hook] avg validation loss = 0.5401
# [07/05 16:06:56 d2.utils.events]:  eta: 0:02:24  iter: 2819  total_loss: 0.3811  loss_cls: 0.07439  loss_box_reg: 0.1514  loss_mask: 0.1016  loss_rpn_cls: 0.002357  loss_rpn_loc: 0.03808  validation_total_loss: 0.5401    time: 0.8026  last_time: 0.9349  data_time: 0.3778  last_data_time: 0.0257   lr: 0.00025  max_mem: 3098M
# [07/05 16:07:11 d2.utils.events]:  eta: 0:02:08  iter: 2839  total_loss: 0.3793  loss_cls: 0.07612  loss_box_reg: 0.1596  loss_mask: 0.1025  loss_rpn_cls: 0.001956  loss_rpn_loc: 0.04134  validation_total_loss: 0.5401    time: 0.8022  last_time: 0.7070  data_time: 0.0234  last_data_time: 0.0102   lr: 0.00025  max_mem: 3098M
# [07/05 16:07:25 d2.utils.events]:  eta: 0:01:52  iter: 2859  total_loss: 0.3501  loss_cls: 0.05669  loss_box_reg: 0.1471  loss_mask: 0.1029  loss_rpn_cls: 0.002307  loss_rpn_loc: 0.04356  validation_total_loss: 0.5401    time: 0.8016  last_time: 0.7848  data_time: 0.0189  last_data_time: 0.0118   lr: 0.00025  max_mem: 3098M
# [07/05 16:07:41 d2.utils.events]:  eta: 0:01:35  iter: 2879  total_loss: 0.3719  loss_cls: 0.07099  loss_box_reg: 0.1534  loss_mask: 0.1059  loss_rpn_cls: 0.001236  loss_rpn_loc: 0.04026  validation_total_loss: 0.5401    time: 0.8015  last_time: 0.7035  data_time: 0.0266  last_data_time: 0.0208   lr: 0.00025  max_mem: 3098M
# [07/05 16:07:56 d2.utils.events]:  eta: 0:01:19  iter: 2899  total_loss: 0.3591  loss_cls: 0.07374  loss_box_reg: 0.147  loss_mask: 0.1017  loss_rpn_cls: 0.001944  loss_rpn_loc: 0.03865  validation_total_loss: 0.5401    time: 0.8012  last_time: 0.7918  data_time: 0.0186  last_data_time: 0.0231   lr: 0.00025  max_mem: 3098M
# [07/05 16:08:11 d2.utils.events]:  eta: 0:01:03  iter: 2919  total_loss: 0.3643  loss_cls: 0.06437  loss_box_reg: 0.1598  loss_mask: 0.1041  loss_rpn_cls: 0.001405  loss_rpn_loc: 0.04067  validation_total_loss: 0.5401    time: 0.8008  last_time: 0.8007  data_time: 0.0188  last_data_time: 0.0217   lr: 0.00025  max_mem: 3098M
# [07/05 16:08:26 d2.utils.events]:  eta: 0:00:47  iter: 2939  total_loss: 0.3675  loss_cls: 0.06768  loss_box_reg: 0.1543  loss_mask: 0.1045  loss_rpn_cls: 0.001699  loss_rpn_loc: 0.04001  validation_total_loss: 0.5401    time: 0.8005  last_time: 0.6792  data_time: 0.0198  last_data_time: 0.0155   lr: 0.00025  max_mem: 3098M
# [07/05 16:08:41 d2.utils.events]:  eta: 0:00:31  iter: 2959  total_loss: 0.3628  loss_cls: 0.06382  loss_box_reg: 0.1521  loss_mask: 0.1075  loss_rpn_cls: 0.001335  loss_rpn_loc: 0.03936  validation_total_loss: 0.5401    time: 0.8001  last_time: 0.6461  data_time: 0.0191  last_data_time: 0.0217   lr: 0.00025  max_mem: 3098M
# [07/05 16:08:56 d2.utils.events]:  eta: 0:00:15  iter: 2979  total_loss: 0.3703  loss_cls: 0.06725  loss_box_reg: 0.151  loss_mask: 0.1045  loss_rpn_cls: 0.00134  loss_rpn_loc: 0.04008  validation_total_loss: 0.5401    time: 0.7998  last_time: 0.7854  data_time: 0.0237  last_data_time: 0.0172   lr: 0.00025  max_mem: 3098M
# [07/05 16:09:33 d2.utils.events]:  eta: 0:00:00  iter: 2999  total_loss: 0.3593  loss_cls: 0.06413  loss_box_reg: 0.1489  loss_mask: 0.1038  loss_rpn_cls: 0.002257  loss_rpn_loc: 0.03843  validation_total_loss: 0.5401    time: 0.7995  last_time: 0.6997  data_time: 0.0201  last_data_time: 0.0185   lr: 0.00025  max_mem: 3098M
# [07/05 16:09:33 d2.engine.hooks]: Overall training speed: 2998 iterations in 0:39:56 (0.7995 s / it)
# [07/05 16:09:33 d2.engine.hooks]: Total training time: 0:43:48 (0:03:51 on hooks)
# [07/05 16:09:33 d2.data.datasets.coco]: Loaded 14 images in COCO format from /content/drive/MyDrive/my_dataset/Pollen/val/pollen_val_coco.json
# [07/05 16:09:33 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [07/05 16:09:33 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/05 16:09:33 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [07/05 16:09:33 d2.data.common]: Serialized dataset takes 0.08 MiB
# WARNING [07/05 16:09:33 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [07/05 16:09:33 d2.evaluation.evaluator]: Start inference on 14 batches
# [07/05 16:09:35 d2.evaluation.evaluator]: Inference done 11/14. Dataloading: 0.0013 s/iter. Inference: 0.0873 s/iter. Eval: 0.0210 s/iter. Total: 0.1096 s/iter. ETA=0:00:00
# [07/05 16:09:43 d2.evaluation.evaluator]: Total inference time: 0:00:08.542136 (0.949126 s / iter per device, on 1 devices)
# [07/05 16:09:43 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.090908 s / iter per device, on 1 devices)
# [07/05 16:09:43 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/05 16:09:43 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/my_dataset/pollen_output/inference/coco_instances_results.json
# [07/05 16:09:43 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/05 16:09:43 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/05 16:09:43 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [07/05 16:09:43 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/05 16:09:43 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.02 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.804
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.972
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.932
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.710
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.821
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.287
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.853
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.788
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.867
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [07/05 16:09:43 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 80.374 | 97.165 | 93.243 | 70.964 | 82.142 |  nan  |
# [07/05 16:09:43 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [07/05 16:09:43 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Acer       | 78.303 | Betula     | 82.039 | Ulmaceae   | 80.781 |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [07/05 16:09:43 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [07/05 16:09:43 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.04 seconds.
# [07/05 16:09:43 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/05 16:09:43 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.821
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.972
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.941
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.606
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.861
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.292
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.868
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.796
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.884
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [07/05 16:09:43 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 82.092 | 97.165 | 94.131 | 60.646 | 86.084 |  nan  |
# [07/05 16:09:43 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [07/05 16:09:43 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Acer       | 79.271 | Betula     | 85.417 | Ulmaceae   | 81.587 |
# [07/05 16:09:43 d2.engine.defaults]: Evaluation results for pollen_val in csv format:
# [07/05 16:09:43 d2.evaluation.testing]: copypaste: Task: bbox
# [07/05 16:09:43 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/05 16:09:43 d2.evaluation.testing]: copypaste: 80.3741,97.1649,93.2430,70.9640,82.1418,nan
# [07/05 16:09:43 d2.evaluation.testing]: copypaste: Task: segm
# [07/05 16:09:43 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/05 16:09:43 d2.evaluation.testing]: copypaste: 82.0916,97.1649,94.1314,60.6465,86.0838,nan

# %% [markdown]
# Visualizing train and val total loss

# %%
import json
import pathlib
import pandas as pd
import matplotlib.pyplot as plt

# 读取日志
log_file = pathlib.Path("/content/drive/MyDrive/my_dataset/pollen_output/metrics.json")
records = [json.loads(line) for line in log_file.open()]
df = pd.DataFrame(records)
df = df.drop_duplicates(subset="iteration").sort_values("iteration")

# 绘图
plt.figure(figsize=(10, 5))

# 训练 loss
if "total_loss" in df.columns:
    plt.plot(df["iteration"], df["total_loss"], label="Training Total Loss", color='blue')

# 验证 loss（稀疏点 + marker）
if "validation_total_loss" in df.columns:
    val_df = df[["iteration", "validation_total_loss"]].dropna()
    plt.plot(val_df["iteration"], val_df["validation_total_loss"], label="Validation Total Loss", color='orange', marker='o', linewidth=2)

plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Training vs Validation Total Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Inference using the trained segmentation model

# %%
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2 import model_zoo
from detectron2.data import build_detection_test_loader
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
import os, json

cfg = get_cfg()
cfg.merge_from_file(
    model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
)

cfg.DATASETS.TRAIN = ("pollen_train",)
cfg.DATASETS.TEST = ("pollen_test",)
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 3
cfg.OUTPUT_DIR = "/content/drive/MyDrive/my_dataset/pollen_output"

cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.8   # Confidence threshold
cfg.MODEL.DEVICE = "cuda"

predictor = DefaultPredictor(cfg)

# Evaluating COCO metrics
evaluator = COCOEvaluator("pollen_test", cfg, False, output_dir=cfg.OUTPUT_DIR)
test_loader = build_detection_test_loader(cfg, "pollen_test")
metrics = inference_on_dataset(predictor.model, test_loader, evaluator)
print("Test metrics:", json.dumps(metrics, indent=2))
# Out:
# [07/05 16:14:14 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /content/drive/MyDrive/my_dataset/pollen_output/model_final.pth ...
# WARNING [07/05 16:14:15 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [07/05 16:14:15 d2.data.datasets.coco]: Loaded 14 images in COCO format from /content/drive/MyDrive/my_dataset/Pollen/test/pollen_test_coco.json
# [07/05 16:14:15 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |    Acer    | 107          |   Betula   | 98           |  Ulmaceae  | 275          |
# |            |              |            |              |            |              |
# |   total    | 480          |            |              |            |              |
# [07/05 16:14:15 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [07/05 16:14:15 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/05 16:14:15 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [07/05 16:14:15 d2.data.common]: Serialized dataset takes 0.08 MiB
# [07/05 16:14:15 d2.evaluation.evaluator]: Start inference on 14 batches
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# [07/05 16:14:16 d2.evaluation.evaluator]: Inference done 11/14. Dataloading: 0.0009 s/iter. Inference: 0.0837 s/iter. Eval: 0.0209 s/iter. Total: 0.1055 s/iter. ETA=0:00:00
# [07/05 16:14:17 d2.evaluation.evaluator]: Total inference time: 0:00:01.108880 (0.123209 s / iter per device, on 1 devices)
# [07/05 16:14:17 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.085198 s / iter per device, on 1 devices)
# [07/05 16:14:18 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/05 16:14:18 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/my_dataset/pollen_output/coco_instances_results.json
# [07/05 16:14:18 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/05 16:14:18 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/05 16:14:18 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.01 seconds.
# [07/05 16:14:18 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/05 16:14:18 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.780
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.943
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.650
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.822
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.693
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.841
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [07/05 16:14:18 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 78.016 | 94.271 | 92.270 | 64.952 | 79.982 |  nan  |
# [07/05 16:14:18 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [07/05 16:14:18 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Acer       | 76.357 | Betula     | 81.223 | Ulmaceae   | 76.468 |
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/05 16:14:18 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [07/05 16:14:18 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [07/05 16:14:18 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/05 16:14:18 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.809
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.943
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.916
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.634
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.835
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.847
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.721
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.864
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [07/05 16:14:18 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 80.881 | 94.271 | 91.553 | 63.433 | 83.489 |  nan  |
# [07/05 16:14:18 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [07/05 16:14:18 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Acer       | 79.088 | Betula     | 85.916 | Ulmaceae   | 77.638 |
# Test metrics: {
#   "bbox": {
#     "AP": 78.01602592478154,
#     "AP50": 94.27137523182486,
#     "AP75": 92.26957692683906,
#     "APs": 64.95210788103125,
#     "APm": 79.98195939462612,
#     "APl": NaN,
#     "AP-Acer": 76.35712508406252,
#     "AP-Betula": 81.22337725925772,
#     "AP-Ulmaceae": 76.46757543102441
#   },
#   "segm": {
#     "AP": 80.88070430270837,
#     "AP50": 94.27137523182486,
#     "AP75": 91.55265221120243,
#     "APs": 63.43310052705466,
#     "APm": 83.4890858514379,
#     "APl": NaN,
#     "AP-Acer": 79.08799996599333,
#     "AP-Betula": 85.9157373337426,
#     "AP-Ulmaceae": 77.63837560838913
#   }
# }

# %% [markdown]
# Use segmentation model to crop and save pollen instances

# %%
import os, cv2, torch
from glob import glob
from tqdm import tqdm
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2 import model_zoo
import re

# Set input directories for training and validation images
train_dir = "/content/drive/MyDrive/my_dataset/Pollen/train"
val_dir = "/content/drive/MyDrive/my_dataset/Pollen/val"
all_images = glob(f"{train_dir}/*.png") + glob(f"{val_dir}/*.png")

# Set output directory for cropped pollen images
save_root = "/content/drive/MyDrive/my_dataset/Classification"
os.makedirs(save_root, exist_ok=True)

# List of pollen species
species_list = ["Acer", "Betula", "Ulmaceae"]
for sp in species_list:
    os.makedirs(os.path.join(save_root, sp), exist_ok=True)

# Start batch processing
print(f"Found {len(all_images)} images. Starting inference and crop saving...")

for img_path in tqdm(all_images):
    # Determine species from filename prefix
    filename = os.path.basename(img_path)
    matched = [sp for sp in species_list if filename.startswith(sp)]
    if not matched:
        print(f"Skipping unknown species: {filename}")
        continue
    species = matched[0]

    # Inference using trained Detectron2 segmentation model
    image = cv2.imread(img_path)
    outputs = predictor(image)
    boxes = outputs["instances"].pred_boxes.tensor.cpu().numpy()

    # Crop and save each detected instance
    for i, box in enumerate(boxes):
        x1, y1, x2, y2 = map(int, box)
        crop = image[y1:y2, x1:x2]

        # Convert to grayscale
        gray_crop = cv2.cvtColor(crop, cv2.COLOR_BGR2GRAY)

        # Extract 4-digit tile ID from filename
        basename = os.path.splitext(filename)[0]
        match = re.search(r"tile_(\d{4})", basename)
        img_id = match.group(1) if match else "0000"

        # Construct simplified filename, e.g., Acer_0051_crop0.jpg
        new_name = f"{species}_{img_id}_crop{i}.jpg"
        out_path = os.path.join(save_root, species, new_name)

        # Save the cropped grayscale image
        cv2.imwrite(out_path, gray_crop)

print("All crops have been saved successfully.")
# Out:
# Found 102 images. Starting inference and crop saving...
# 100%|██████████| 102/102 [19:02<00:00, 11.20s/it]
# ✅ All crops have been saved successfully.

# %% [markdown]
# Visualize the image

# %%
import os
import random
import cv2
import matplotlib.pyplot as plt

# 设置保存图像的根目录（与你上面代码中的 save_root 相同）
save_root = "/content/drive/MyDrive/my_dataset/Classification"

# 遍历所有子类文件夹，收集所有图像路径
all_saved_images = []
for sp in os.listdir(save_root):
    sp_dir = os.path.join(save_root, sp)
    if os.path.isdir(sp_dir):
        image_files = [os.path.join(sp_dir, f) for f in os.listdir(sp_dir) if f.endswith(".jpg")]
        all_saved_images.extend(image_files)

# 随机选取 3 张图像
sample_images = random.sample(all_saved_images, 3)

# 显示图像
plt.figure(figsize=(12, 4))
for i, img_path in enumerate(sample_images):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    plt.subplot(1, 3, i + 1)
    plt.imshow(img, cmap='gray')
    plt.title(os.path.basename(img_path), fontsize=12)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Extracting basic information from pollen images

# %%
import os
from collections import defaultdict
import matplotlib.pyplot as plt

# Font settings
plt.rcParams['font.sans-serif'] = ['DejaVu Sans']
plt.rcParams['font.size'] = 12
plt.rcParams['axes.unicode_minus'] = False

# Path to dataset
data_dir = "/content/drive/MyDrive/my_dataset/Classification_uniform"

# Count images per species
species_counts = defaultdict(int)
for species in os.listdir(data_dir):
    sp_dir = os.path.join(data_dir, species)
    if os.path.isdir(sp_dir):
        images = [f for f in os.listdir(sp_dir) if f.endswith(".jpg")]
        species_counts[species] = len(images)

# 文件夹名到学名的映射
name_map = {
    "Acer": "Acer monspessulanum",
    "Betula": "Betula pendula",
    "Ulmaceae": "Ulmus hollandica"
}

# Order: Acer → Betula → Ulmaceae
desired_order = ["Acer", "Betula", "Ulmaceae"]
ordered_counts = {name_map[sp]: species_counts[sp] for sp in desired_order}

# Plot
plt.figure(figsize=(8, 5))
bars = plt.bar(ordered_counts.keys(), ordered_counts.values(), color='skyblue')
plt.ylim(0, max(ordered_counts.values()) * 1.15)

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height + 10, f'{height:.0f}',
             ha='center', va='bottom', fontsize=11)

plt.title("Number of Tiles per Species (Classification Dataset)")
plt.xlabel("Pollen Species")
plt.ylabel("Image Count")
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# Crop pollen instances using segmentation masks and save with transparent background 花粉边框

# %%
import os
import cv2
import numpy as np
import re
from tqdm import tqdm
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2 import model_zoo

# 设置分割模型配置
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file(
    "COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.WEIGHTS = "/content/drive/MyDrive/my_dataset/pollen_output/model_final.pth"
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 3
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.8
cfg.MODEL.DEVICE = "cuda"

predictor = DefaultPredictor(cfg)

# 物种及其原始图像目录
species_list = ["Acer", "Betula", "Ulmaceae"]
base_dir = "/content/drive/MyDrive/my_dataset"
image_dirs = [os.path.join(base_dir, f"{sp}_tiles_downsampled_512") for sp in species_list]

# 输出目录
save_root = os.path.join(base_dir, "MaskedTransparent")
os.makedirs(save_root, exist_ok=True)
for sp in species_list:
    os.makedirs(os.path.join(save_root, sp), exist_ok=True)

# 批量处理所有图像
for sp, sp_dir in zip(species_list, image_dirs):
    image_files = [f for f in os.listdir(sp_dir) if f.lower().endswith(".png")]

    for fname in tqdm(image_files, desc=f"Processing {sp}"):
        img_path = os.path.join(sp_dir, fname)
        image = cv2.imread(img_path)
        if image is None:
            continue

        outputs = predictor(image)
        masks = outputs["instances"].pred_masks.cpu().numpy()

        for i, mask in enumerate(masks):
            mask = mask.astype(np.uint8) * 255
            ys, xs = np.where(mask > 0)
            if len(xs) == 0 or len(ys) == 0:
                continue
            x1, y1, x2, y2 = min(xs), min(ys), max(xs), max(ys)
            crop_img = image[y1:y2+1, x1:x2+1]
            crop_mask = mask[y1:y2+1, x1:x2+1]

            # 创建透明图像（BGRA）
            crop_bgra = cv2.cvtColor(crop_img, cv2.COLOR_BGR2BGRA)
            crop_bgra[:, :, 3] = crop_mask  # 设置 alpha 通道

            # 命名方式：包含 slide ID 和 tile 编号
            match_tile = re.search(r"tile_(\d{4})", fname)
            tile_id = match_tile.group(1) if match_tile else "xxxx"

            match_slide = re.search(r"(BM_\d+)", fname)
            slide_id = match_slide.group(1) if match_slide else "BM_xxxx"

            out_name = f"{sp}_{slide_id}_{tile_id}_mask{i}.png"
            out_path = os.path.join(save_root, sp, out_name)
            cv2.imwrite(out_path, crop_bgra)

print("All pollen images have been saved as transparent images")
# Out:
# Processing Acer: 100%|██████████| 182/182 [00:39<00:00,  4.57it/s]
# Processing Betula: 100%|██████████| 222/222 [01:08<00:00,  3.24it/s]
# Processing Ulmaceae: 100%|██████████| 768/768 [06:33<00:00,  1.95it/s]
# All pollen images have been saved as transparent images

# %% [markdown]
# Visualization

# %%
import os
import random
import cv2
import matplotlib.pyplot as plt

# 图像目录
base_dir = "/content/drive/MyDrive/my_dataset/MaskedTransparent"
species_list = ["Acer", "Betula", "Ulmaceae"]

# 收集所有图像路径
all_images = []
for sp in species_list:
    sp_dir = os.path.join(base_dir, sp)
    files = [os.path.join(sp_dir, f) for f in os.listdir(sp_dir) if f.endswith(".png")]
    all_images.extend(files)

# 随机选取 3 张图像
sample_paths = random.sample(all_images, 3)

# 可视化
plt.figure(figsize=(12, 4))
for i, path in enumerate(sample_paths):
    img = cv2.imread(path, cv2.IMREAD_UNCHANGED)  # 保留 alpha 通道
    img_rgb = cv2.cvtColor(img[:, :, :3], cv2.COLOR_BGR2RGB)
    alpha = img[:, :, 3]

    # 将透明区域变为灰色背景（可选）
    img_rgb[alpha == 0] = [220, 220, 220]

    plt.subplot(1, 3, i + 1)
    plt.imshow(img_rgb)
    plt.title(os.path.basename(path))
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import os
from collections import defaultdict
import matplotlib.pyplot as plt

# 设置字体和样式
plt.rcParams['font.sans-serif'] = ['DejaVu Sans']
plt.rcParams['font.size'] = 12
plt.rcParams['axes.unicode_minus'] = False

# 数据集路径：MaskedTransparent 文件夹
data_dir = "/content/drive/MyDrive/my_dataset/MaskedTransparent"

# 统计每个物种的图像数量
species_counts = defaultdict(int)
for species in os.listdir(data_dir):
    sp_dir = os.path.join(data_dir, species)
    if os.path.isdir(sp_dir):
        images = [f for f in os.listdir(sp_dir) if f.lower().endswith(".png")]
        species_counts[species] = len(images)

# 文件夹名 -> 学名
name_map = {
    "Acer": "Acer monspessulanum",
    "Betula": "Betula pendula",
    "Ulmaceae": "Ulmus hollandica"
}

# 保持顺序：Acer → Betula → Ulmaceae
desired_order = ["Acer", "Betula", "Ulmaceae"]
ordered_counts = {name_map[sp]: species_counts[sp] for sp in desired_order}

# 绘图
plt.figure(figsize=(8, 5))
bars = plt.bar(ordered_counts.keys(), ordered_counts.values(), color='skyblue')

plt.ylim(0, max(ordered_counts.values()) * 1.15)

# 添加数值标签
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height + 10, f'{height:.0f}',
             ha='center', va='bottom', fontsize=11)

plt.title("Number of Individual Pollen Images per Species")
plt.xlabel("Pollen Species")
plt.ylabel("Image Count")
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Classification model ResNet50

# %% [markdown]
# Count the maximum size of crops

# %%
import os
import cv2

base_dir = "/content/drive/MyDrive/my_dataset/Classification"
species_list = ["Acer", "Betula", "Ulmaceae"]

max_h, max_w = 0, 0

for sp in species_list:
    folder = os.path.join(base_dir, sp)
    for f in os.listdir(folder):
        if f.endswith(".jpg"):
            img = cv2.imread(os.path.join(folder, f), cv2.IMREAD_GRAYSCALE)
            if img is not None:
                h, w = img.shape
                max_h = max(max_h, h)
                max_w = max(max_w, w)

print(f"Maximum pollen size：height = {max_h}, width = {max_w}")
# Out:
# Maximum pollen size：height = 84, width = 66

# %% [markdown]
# Center alignment + black border padding

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

# 固定目标尺寸
TARGET_H, TARGET_W = 84, 84
PAD_COLOR = 0  # 黑色背景

# 输入输出路径
src_root = "/content/drive/MyDrive/my_dataset/Classification"
dst_root = "/content/drive/MyDrive/my_dataset/Classification_uniform"
species_list = ["Acer", "Betula", "Ulmaceae"]

# 中心填充函数（不缩放）
def pad_to_target_size(img, target_h, target_w, pad_value=0):
    h, w = img.shape
    assert h <= target_h and w <= target_w, f"Image larger than target: {h}x{w}"

    pad_top = (target_h - h) // 2
    pad_bottom = target_h - h - pad_top
    pad_left = (target_w - w) // 2
    pad_right = target_w - w - pad_left

    padded = cv2.copyMakeBorder(
        img, pad_top, pad_bottom, pad_left, pad_right,
        borderType=cv2.BORDER_CONSTANT, value=pad_value
    )
    return padded

# 批处理每类图像
for sp in species_list:
    src_dir = os.path.join(src_root, sp)
    dst_dir = os.path.join(dst_root, sp)
    os.makedirs(dst_dir, exist_ok=True)

    for fname in tqdm(os.listdir(src_dir), desc=f"Processing {sp}"):
        if not fname.endswith(".jpg"):
            continue
        src_path = os.path.join(src_dir, fname)
        dst_path = os.path.join(dst_dir, fname)

        img = cv2.imread(src_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"Read failed: {fname}")
            continue

        h, w = img.shape
        if h > TARGET_H or w > TARGET_W:
            print(f"Image too large, skipping: {fname} ({h}x{w})")
            continue

        padded = pad_to_target_size(img, TARGET_H, TARGET_W, pad_value=PAD_COLOR)
        cv2.imwrite(dst_path, padded)

print("All crops have saved.")
# Out:
# Processing Acer: 100%|██████████| 677/677 [06:14<00:00,  1.81it/s]
# Processing Betula: 100%|██████████| 933/933 [09:04<00:00,  1.71it/s]
# Processing Ulmaceae: 100%|██████████| 1350/1350 [12:12<00:00,  1.84it/s]
# All crops have saved.

# %% [markdown]
# resize成224像素 transforms.Resize

# %%
from torchvision import transforms
from torchvision.transforms import InterpolationMode

transform = transforms.Compose([
    transforms.Resize((224, 224), interpolation=InterpolationMode.BICUBIC),  # 缩放
    transforms.Grayscale(num_output_channels=3),  # 转灰度但保留3通道
    transforms.ToTensor(),  # 转Tensor并把像素从0-255归一化到0-1
    transforms.Normalize(mean=[0.485, 0.456, 0.406],  # 标准化
                         std=[0.229, 0.224, 0.225]),
])

# %% [markdown]
# Visual inspection

# %%
import os, random
import matplotlib.pyplot as plt
from torchvision import datasets, transforms
from torchvision.transforms import InterpolationMode

data_dir = "/content/drive/MyDrive/my_dataset/Classification_uniform"

tf = transforms.Compose([
    transforms.Resize((224, 224), interpolation=InterpolationMode.BICUBIC),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor()
])

ds = datasets.ImageFolder(data_dir, transform=tf)
print("类别顺序：", ds.classes)

# 想要的顺序（小写写法也行）
wanted = ["acer", "betula", "ulmaceae"]

# 把数据集里的真实类名映射为小写 -> 原名，兼容大小写
name_map = {c.lower(): c for c in ds.classes}
target_classes = [name_map[w] for w in wanted]  # 如果某个类不存在会 KeyError

fig, axes = plt.subplots(1, 3, figsize=(12, 4))
for ax, cls_name in zip(axes, target_classes):
    cls_idx = ds.class_to_idx[cls_name]  # 官方映射，更稳
    # 找到该类别的所有样本索引
    indices = [i for i, (_, y) in enumerate(ds.samples) if y == cls_idx]
    idx = random.choice(indices)
    img, label = ds[idx]
    ax.imshow(img.permute(1, 2, 0))  # 已是3通道，不需要 cmap
    ax.set_title(cls_name)
    ax.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 类别顺序： ['Acer', 'Betula', 'Ulmaceae']

# %% [markdown]
# 2025.8.16 晚上9点 有正则化 有数据增强 旋转180度

# %%
# ========= 1) Imports & Reproducibility =========
import os, random, numpy as np, torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms, models
from torchvision.transforms import InterpolationMode
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt

def set_seed(s=42):
    random.seed(s); np.random.seed(s); torch.manual_seed(s)
    torch.cuda.manual_seed_all(s)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device:", device)

# ========= 2) Config（可改参数） =========
data_dir      = "/content/drive/MyDrive/my_dataset/Classification_uniform"
batch_size    = 16
epochs        = 60
lr            = 1e-6
weight_decay  = 1e-4
val_ratio     = 0.15
test_ratio    = 0.15
num_workers   = 2
split_cache   = os.path.join(data_dir, f"split_v{int(val_ratio*100)}_{int(test_ratio*100)}.npz")
save_best_to  = os.path.join(data_dir, "best_model_val_macroF1.pt")

# ========= 3) Transforms（轻微旋转±180°，黑色填充；验证/测试不随机） =========
train_tf = transforms.Compose([
    transforms.Resize((224, 224), interpolation=InterpolationMode.BICUBIC),
    transforms.RandomRotation(180, fill=0),       # 随机旋转范围为 ±180°
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406],
                         std =[0.229,0.224,0.225]),
])
eval_tf = transforms.Compose([
    transforms.Resize((224, 224), interpolation=InterpolationMode.BICUBIC),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406],
                         std =[0.229,0.224,0.225]),
])

# ========= 4) Datasets & Split（生成或读取固定 70/15/15 划分） =========
base_ds   = datasets.ImageFolder(data_dir)
targets   = np.array(base_ds.targets)
classes   = base_ds.classes
n_classes = len(classes)
print("Classes:", classes)

if os.path.exists(split_cache):
    npz = np.load(split_cache)
    train_idx, val_idx, test_idx = npz["train"], npz["val"], npz["test"]
    print(">>> 读取已有划分：", split_cache)
else:
    print(">>> 生成新的 70/15/15 分层划分并缓存：", split_cache)
    idx_all = np.arange(len(targets))
    # 先拆 test
    sss1 = StratifiedShuffleSplit(n_splits=1, test_size=test_ratio, random_state=42)
    trval_idx, test_idx = next(sss1.split(idx_all, targets))
    # 再从剩余里拆 val
    val_size = val_ratio / (1.0 - test_ratio)
    sss2 = StratifiedShuffleSplit(n_splits=1, test_size=val_size, random_state=42)
    train_i, val_i = next(sss2.split(trval_idx, targets[trval_idx]))
    train_idx = trval_idx[train_i]
    val_idx   = trval_idx[val_i]
    # 断言不重叠
    assert set(train_idx).isdisjoint(val_idx)
    assert set(train_idx).isdisjoint(test_idx)
    assert set(val_idx).isdisjoint(test_idx)
    np.savez(split_cache, train=train_idx, val=val_idx, test=test_idx)

# 应用 transforms 构建子集
full_eval_ds = datasets.ImageFolder(data_dir, transform=eval_tf)
train_aug_ds = datasets.ImageFolder(data_dir, transform=train_tf)
train_ds = Subset(train_aug_ds, train_idx)
val_ds   = Subset(full_eval_ds, val_idx)
test_ds  = Subset(full_eval_ds, test_idx)  # 测试集第二部分再评估

# ========= 5) DataLoaders =========
pin = (device.type == 'cuda')
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True,  num_workers=num_workers, pin_memory=pin)
val_dl   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin)
test_dl  = DataLoader(test_ds,  batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin)

# ========= 6) Model =========
model = models.resnet101(weights=models.ResNet101_Weights.DEFAULT)
model.fc = nn.Linear(model.fc.in_features, n_classes)
model = model.to(device)

# ========= 7) Loss（自动类别权重） & Optimizer（含 weight_decay） =========
train_targets = targets[train_idx]
counts  = np.bincount(train_targets, minlength=n_classes)
inv     = 1.0 / np.maximum(counts, 1)   # 算每个类别数量的“倒数”（数量少 → 倒数大）
weights = inv / inv.mean()   # 除以它们的平均值，做归一化
class_weights = torch.tensor(weights, dtype=torch.float32, device=device)
print("Class counts (train):", counts, "| class_weights:", np.round(weights, 3))

criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

# ========= 8) Train + Validate（按验证集 macro-F1 保存最佳） =========
train_loss_list, val_loss_list = [], []
train_acc_list,  val_acc_list  = [], []
best_metric, best_state = -1.0, None

for epoch in range(1, epochs + 1):
    # ---- Train ----
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    for x, y in train_dl:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad(set_to_none=True)
        out  = model(x)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * x.size(0)
        pred = out.argmax(1)
        correct += (pred == y).sum().item()
        total   += y.size(0)

    train_loss = running_loss / max(total, 1)
    train_acc  = 100.0 * correct / max(total, 1)
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    # ---- Validate ----
    model.eval()
    v_running_loss, v_correct, v_total = 0.0, 0, 0
    all_val_preds, all_val_labels = [], []
    with torch.no_grad():
        for x, y in val_dl:
            x, y = x.to(device), y.to(device)
            out  = model(x)
            loss = criterion(out, y)
            v_running_loss += loss.item() * x.size(0)
            pred = out.argmax(1)
            v_correct += (pred == y).sum().item()
            v_total   += y.size(0)
            all_val_preds.append(pred.cpu())
            all_val_labels.append(y.cpu())

    val_loss = v_running_loss / max(v_total, 1)
    val_acc  = 100.0 * v_correct / max(v_total, 1)
    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)

    yv = torch.cat(all_val_labels).numpy()
    pv = torch.cat(all_val_preds).numpy()
    val_macro_f1 = f1_score(yv, pv, average='macro')

    if val_macro_f1 > best_metric:
        best_metric = val_macro_f1
        best_state  = {k: v.detach().cpu() for k, v in model.state_dict().items()}
        torch.save(best_state, save_best_to)

    print(f"Epoch {epoch:02d}/{epochs} | "
          f"Train Loss {train_loss:.4f} Acc {train_acc:.2f}% | "
          f"Val Loss {val_loss:.4f} Acc {val_acc:.2f}% | "
          f"Val macro-F1 {val_macro_f1:.3f}")

# 训练结束：加载验证集最佳权重（供第二部分测试使用）
if best_state is not None:
    model.load_state_dict({k: v.to(device) for k, v in best_state.items()})
    print(f"\nLoaded best weights by val macro-F1 = {best_metric:.3f} from '{save_best_to}'")
else:
    print("\n[Warning] No best_state saved. Check your training loop.")

# ========= 9) Plot Curves（train/val 的 loss 与 accuracy 对比曲线） =========
epochs_axis = range(1, len(train_loss_list)+1)

plt.figure(figsize=(7,5))
plt.plot(epochs_axis, train_loss_list, marker='o', label='Train Loss')
plt.plot(epochs_axis, val_loss_list,   marker='s', label='Val Loss')
plt.title('Loss over Epochs'); plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.grid(True); plt.legend(); plt.tight_layout(); plt.show()

plt.figure(figsize=(7,5))
plt.plot(epochs_axis, train_acc_list, marker='o', label='Train Acc')
plt.plot(epochs_axis, val_acc_list,   marker='s', label='Val Acc')
plt.title('Accuracy over Epochs'); plt.xlabel('Epoch'); plt.ylabel('Accuracy (%)')
plt.grid(True); plt.legend(); plt.tight_layout(); plt.show()
# Out:
# Device: cuda
# Classes: ['Acer', 'Betula', 'Ulmaceae']
# >>> 读取已有划分： /content/drive/MyDrive/my_dataset/Classification_uniform/split_v15_15.npz
# Downloading: "https://download.pytorch.org/models/resnet101-cd907fc2.pth" to /root/.cache/torch/hub/checkpoints/resnet101-cd907fc2.pth
# 100%|██████████| 171M/171M [00:00<00:00, 185MB/s]
# Class counts (train): [473 653 923] | class_weights: [1.341 0.971 0.687]
# Epoch 01/60 | Train Loss 1.0729 Acc 40.56% | Val Loss 1.2417 Acc 34.55% | Val macro-F1 0.294
# Epoch 02/60 | Train Loss 1.0161 Acc 59.05% | Val Loss 1.1204 Acc 62.27% | Val macro-F1 0.546
# Epoch 03/60 | Train Loss 0.9417 Acc 75.31% | Val Loss 1.1388 Acc 68.41% | Val macro-F1 0.580
# Epoch 04/60 | Train Loss 0.8588 Acc 78.97% | Val Loss 1.0308 Acc 72.73% | Val macro-F1 0.658
# Epoch 05/60 | Train Loss 0.7747 Acc 80.33% | Val Loss 0.9351 Acc 73.18% | Val macro-F1 0.670
# Epoch 06/60 | Train Loss 0.7126 Acc 81.02% | Val Loss 0.8396 Acc 74.77% | Val macro-F1 0.698
# Epoch 07/60 | Train Loss 0.6443 Acc 82.09% | Val Loss 0.7792 Acc 77.73% | Val macro-F1 0.733
# Epoch 08/60 | Train Loss 0.5980 Acc 82.24% | Val Loss 0.8746 Acc 75.45% | Val macro-F1 0.722
# Epoch 09/60 | Train Loss 0.5585 Acc 82.38% | Val Loss 0.6775 Acc 77.50% | Val macro-F1 0.746
# Epoch 10/60 | Train Loss 0.5266 Acc 82.92% | Val Loss 0.7083 Acc 78.18% | Val macro-F1 0.756
# Epoch 11/60 | Train Loss 0.5026 Acc 82.67% | Val Loss 0.6893 Acc 80.45% | Val macro-F1 0.788
# Epoch 12/60 | Train Loss 0.4672 Acc 83.94% | Val Loss 0.6315 Acc 80.45% | Val macro-F1 0.780
# Epoch 13/60 | Train Loss 0.4495 Acc 83.94% | Val Loss 0.6163 Acc 81.36% | Val macro-F1 0.800
# Epoch 14/60 | Train Loss 0.4319 Acc 84.82% | Val Loss 0.5969 Acc 80.68% | Val macro-F1 0.790
# Epoch 15/60 | Train Loss 0.4082 Acc 85.41% | Val Loss 0.5972 Acc 79.77% | Val macro-F1 0.774
# Epoch 16/60 | Train Loss 0.3916 Acc 85.75% | Val Loss 0.6763 Acc 79.77% | Val macro-F1 0.776
# Epoch 17/60 | Train Loss 0.3680 Acc 86.63% | Val Loss 0.4606 Acc 84.77% | Val macro-F1 0.830
# Epoch 18/60 | Train Loss 0.3490 Acc 87.31% | Val Loss 0.4575 Acc 84.09% | Val macro-F1 0.825
# Epoch 19/60 | Train Loss 0.3355 Acc 87.46% | Val Loss 0.4640 Acc 87.50% | Val macro-F1 0.868
# Epoch 20/60 | Train Loss 0.3174 Acc 88.48% | Val Loss 0.6367 Acc 83.86% | Val macro-F1 0.827
# Epoch 21/60 | Train Loss 0.3022 Acc 89.70% | Val Loss 0.5098 Acc 85.68% | Val macro-F1 0.847
# Epoch 22/60 | Train Loss 0.2809 Acc 89.41% | Val Loss 0.4940 Acc 87.05% | Val macro-F1 0.865
# Epoch 23/60 | Train Loss 0.2676 Acc 90.53% | Val Loss 0.4361 Acc 87.73% | Val macro-F1 0.870
# Epoch 24/60 | Train Loss 0.2614 Acc 90.82% | Val Loss 0.4095 Acc 87.05% | Val macro-F1 0.865
# Epoch 25/60 | Train Loss 0.2560 Acc 91.36% | Val Loss 0.4431 Acc 88.41% | Val macro-F1 0.880
# Epoch 26/60 | Train Loss 0.2313 Acc 92.48% | Val Loss 0.3814 Acc 88.18% | Val macro-F1 0.876
# Epoch 27/60 | Train Loss 0.2293 Acc 92.58% | Val Loss 0.3443 Acc 90.68% | Val macro-F1 0.902
# Epoch 28/60 | Train Loss 0.2076 Acc 93.02% | Val Loss 0.3784 Acc 89.09% | Val macro-F1 0.885
# Epoch 29/60 | Train Loss 0.2041 Acc 93.46% | Val Loss 0.3129 Acc 89.77% | Val macro-F1 0.891
# Epoch 30/60 | Train Loss 0.1977 Acc 94.00% | Val Loss 0.3283 Acc 90.00% | Val macro-F1 0.894
# Epoch 31/60 | Train Loss 0.1852 Acc 94.53% | Val Loss 0.3289 Acc 90.23% | Val macro-F1 0.896
# Epoch 32/60 | Train Loss 0.1973 Acc 93.70% | Val Loss 0.3236 Acc 90.00% | Val macro-F1 0.894
# Epoch 33/60 | Train Loss 0.1804 Acc 94.49% | Val Loss 0.2728 Acc 91.59% | Val macro-F1 0.912
# Epoch 34/60 | Train Loss 0.1691 Acc 94.78% | Val Loss 0.2308 Acc 92.95% | Val macro-F1 0.925
# Epoch 35/60 | Train Loss 0.1715 Acc 94.05% | Val Loss 0.2865 Acc 90.91% | Val macro-F1 0.905
# Epoch 36/60 | Train Loss 0.1690 Acc 94.34% | Val Loss 0.4514 Acc 88.64% | Val macro-F1 0.882
# Epoch 37/60 | Train Loss 0.1721 Acc 94.49% | Val Loss 0.3602 Acc 89.77% | Val macro-F1 0.892
# Epoch 38/60 | Train Loss 0.1642 Acc 94.97% | Val Loss 0.2735 Acc 90.23% | Val macro-F1 0.896
# Epoch 39/60 | Train Loss 0.1446 Acc 95.12% | Val Loss 0.3201 Acc 90.91% | Val macro-F1 0.902
# Epoch 40/60 | Train Loss 0.1534 Acc 95.41% | Val Loss 0.3109 Acc 91.14% | Val macro-F1 0.908
# Epoch 41/60 | Train Loss 0.1437 Acc 95.41% | Val Loss 0.1926 Acc 93.64% | Val macro-F1 0.932
# Epoch 42/60 | Train Loss 0.1644 Acc 94.49% | Val Loss 0.2802 Acc 90.23% | Val macro-F1 0.894
# Epoch 43/60 | Train Loss 0.1389 Acc 95.46% | Val Loss 0.1897 Acc 93.86% | Val macro-F1 0.936
# Epoch 44/60 | Train Loss 0.1346 Acc 95.46% | Val Loss 0.4205 Acc 88.86% | Val macro-F1 0.879
# Epoch 45/60 | Train Loss 0.1464 Acc 95.31% | Val Loss 0.2009 Acc 93.41% | Val macro-F1 0.931
# Epoch 46/60 | Train Loss 0.1424 Acc 95.22% | Val Loss 0.1754 Acc 94.32% | Val macro-F1 0.940
# Epoch 47/60 | Train Loss 0.1327 Acc 95.56% | Val Loss 0.3241 Acc 89.55% | Val macro-F1 0.889
# Epoch 48/60 | Train Loss 0.1223 Acc 96.24% | Val Loss 0.1796 Acc 94.09% | Val macro-F1 0.937
# Epoch 49/60 | Train Loss 0.1251 Acc 95.46% | Val Loss 0.2649 Acc 91.59% | Val macro-F1 0.908
# Epoch 50/60 | Train Loss 0.1193 Acc 96.73% | Val Loss 0.1542 Acc 94.77% | Val macro-F1 0.944
# Epoch 51/60 | Train Loss 0.1204 Acc 96.14% | Val Loss 0.2307 Acc 92.50% | Val macro-F1 0.920
# Epoch 52/60 | Train Loss 0.1272 Acc 95.85% | Val Loss 0.1607 Acc 95.23% | Val macro-F1 0.950
# Epoch 53/60 | Train Loss 0.1175 Acc 96.24% | Val Loss 0.2064 Acc 93.64% | Val macro-F1 0.934
# Epoch 54/60 | Train Loss 0.1122 Acc 96.53% | Val Loss 0.1747 Acc 95.00% | Val macro-F1 0.949
# Epoch 55/60 | Train Loss 0.1032 Acc 96.63% | Val Loss 0.1701 Acc 94.32% | Val macro-F1 0.940
# Epoch 56/60 | Train Loss 0.1097 Acc 96.39% | Val Loss 0.2218 Acc 93.41% | Val macro-F1 0.933
# Epoch 57/60 | Train Loss 0.1019 Acc 96.49% | Val Loss 0.1484 Acc 95.23% | Val macro-F1 0.948
# Epoch 58/60 | Train Loss 0.1142 Acc 96.19% | Val Loss 0.1604 Acc 94.09% | Val macro-F1 0.936
# Epoch 59/60 | Train Loss 0.1140 Acc 96.34% | Val Loss 0.2053 Acc 94.09% | Val macro-F1 0.937
# Epoch 60/60 | Train Loss 0.1033 Acc 95.95% | Val Loss 0.1650 Acc 94.77% | Val macro-F1 0.944
#
# Loaded best weights by val macro-F1 = 0.950 from '/content/drive/MyDrive/my_dataset/Classification_uniform/best_model_val_macroF1.pt'

# %% [markdown]
# 验证分类模型

# %%
# ===== Standalone: Load best weights & evaluate on test set =====
import os, torch, numpy as np
import torch.nn as nn
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms, models
from torchvision.transforms import InterpolationMode
from sklearn.metrics import (
    classification_report, confusion_matrix, ConfusionMatrixDisplay,
    f1_score, accuracy_score, balanced_accuracy_score
)
import matplotlib.pyplot as plt

# ----- 0) 基本配置（按你的实际路径改这两项） -----
data_dir   = "/content/drive/MyDrive/my_dataset/Classification_uniform"
ckpt_path  = os.path.join(data_dir, "best_model_val_macroF1.pt")  # 和训练时一致
val_ratio  = 0.15
test_ratio = 0.15
split_cache = os.path.join(data_dir, f"split_v{int(val_ratio*100)}_{int(test_ratio*100)}.npz")

# ----- 1) 设备 -----
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device:", device)

# ----- 2) 只需评估用的 transform -----
eval_tf = transforms.Compose([
    transforms.Resize((224, 224), interpolation=InterpolationMode.BICUBIC),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225]),
])

# ----- 3) 读取数据集 & 固定划分（与训练一致：读取 split_cache）-----
# 注意：这里不用训练集/验证集，只构建测试集 DataLoader
base_ds   = datasets.ImageFolder(data_dir)           # 仅用于拿 targets/classes
targets   = np.array(base_ds.targets)
classes   = base_ds.classes
n_classes = len(classes)
print("Classes:", classes)

if not os.path.exists(split_cache):
    raise FileNotFoundError(
        f"未找到划分缓存 {split_cache}。\n"
        "请先运行训练脚本（会生成 split_vXX_XX.npz），或者把该文件拷贝到相同路径。"
    )
npz = np.load(split_cache)
test_idx = npz["test"]

full_eval_ds = datasets.ImageFolder(data_dir, transform=eval_tf)
test_ds  = Subset(full_eval_ds, test_idx)
test_dl  = DataLoader(test_ds, batch_size=16, shuffle=False, num_workers=2, pin_memory=(device.type=='cuda'))
print(f"Test set size: {len(test_idx)}")

# ----- 4) 重建模型结构（与训练时一致）-----
try:
    model = models.resnet101(weights=models.ResNet101_Weights.DEFAULT)
except Exception as e:
    print("[Warning] 预训练权重下载失败，改用随机初始化（准确率会受影响）:", repr(e))
    model = models.resnet101(weights=None)

model.fc = nn.Linear(model.fc.in_features, n_classes)
model = model.to(device)

# ----- 5) 加载最佳权重 -----
if os.path.exists(ckpt_path):
    print("Loading checkpoint:", ckpt_path)
    state = torch.load(ckpt_path, map_location=device)
    # 如果保存的是纯 state_dict（你的训练代码就是保存的 state_dict）
    model.load_state_dict(state, strict=True)
    print("Loaded best weights ✓")
else:
    print(f"[Warning] 未找到权重文件：{ckpt_path}\n将使用随机初始化的模型进行评估（仅用于流程检查）。")

# ----- 6) 测试集推理 -----
model.eval()
all_preds, all_labels = [], []
with torch.no_grad():
    for x, y in test_dl:
        out = model(x.to(device)).argmax(1).cpu()
        all_preds.append(out)
        all_labels.append(y)

y_true = torch.cat(all_labels).numpy() if all_labels else np.array([])
y_pred = torch.cat(all_preds).numpy()  if all_preds  else np.array([])

if y_true.size == 0:
    raise RuntimeError("测试集为空或 DataLoader 未正确构建。请检查 data_dir 与 split_cache。")

# ----- 7) 计算指标 -----
acc         = accuracy_score(y_true, y_pred)
macro_f1    = f1_score(y_true, y_pred, average='macro', zero_division=0)
weighted_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
bal_acc     = balanced_accuracy_score(y_true, y_pred)

print("\n=== Test Metrics ===")
print(f"Accuracy        : {acc*100:.2f}%")
print(f"Macro F1        : {macro_f1:.3f}")
print(f"Weighted F1     : {weighted_f1:.3f}")
print(f"Balanced Acc    : {bal_acc:.3f}")

# ----- 8) 分类报告（用数据集中真实类别名，避免手写错位）-----
print("\n=== Classification Report (Test) ===")
print(classification_report(y_true, y_pred, target_names=classes, digits=3, zero_division=0))

# ----- 9) 混淆矩阵（大号数字，占据更大正方形空间；坐标轴不变）-----
import numpy as np
cm = confusion_matrix(y_true, y_pred)

fig, ax = plt.subplots(figsize=(6, 6))   # 方形画布，数字更容易占满
im = ax.imshow(cm, cmap=plt.cm.Blues)

# 坐标轴：与原先一致
ax.set_xticks(np.arange(len(classes)))
ax.set_xticklabels(classes, rotation=45)
ax.set_yticks(np.arange(len(classes)))
ax.set_yticklabels(classes)
ax.set_xlabel("Predicted label")
ax.set_ylabel("True label")
ax.set_title("Test Confusion Matrix (Counts)")

# 在每个格子中央放大号数字；根据底色自动切换黑/白
thresh = cm.max() / 2.0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(
            j, i, str(cm[i, j]),
            ha='center', va='center',
            fontsize=24,
            color='white' if cm[i, j] > thresh else 'black'
        )

ax.set_aspect('equal')   # 正方形格子
plt.tight_layout()
plt.show()
# Out:
# Device: cuda
# Classes: ['Acer', 'Betula', 'Ulmaceae']
# Test set size: 440
# Loading checkpoint: /content/drive/MyDrive/my_dataset/Classification_uniform/best_model_val_macroF1.pt
# Loaded best weights ✓
#
# === Test Metrics ===
# Accuracy        : 95.91%
# Macro F1        : 0.956
# Weighted F1     : 0.959
# Balanced Acc    : 0.957
#
# === Classification Report (Test) ===
#               precision    recall  f1-score   support
#
#         Acer      0.932     0.941     0.937       102
#       Betula      0.965     0.965     0.965       141
#     Ulmaceae      0.969     0.964     0.967       197
#
#     accuracy                          0.959       440
#    macro avg      0.955     0.957     0.956       440
# weighted avg      0.959     0.959     0.959       440

# %%
# ===== Standalone: Load best weights & evaluate on test set =====
import os, torch, numpy as np
import torch.nn as nn
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms, models
from torchvision.transforms import InterpolationMode
from sklearn.metrics import (
    classification_report, confusion_matrix, ConfusionMatrixDisplay,
    f1_score, accuracy_score, balanced_accuracy_score
)
import matplotlib.pyplot as plt

# ----- 0) 基本配置（按你的实际路径改这两项） -----
data_dir   = "/content/drive/MyDrive/my_dataset/Classification_uniform"
ckpt_path  = os.path.join(data_dir, "best_model_val_macroF1.pt")  # 和训练时一致
val_ratio  = 0.15
test_ratio = 0.15
split_cache = os.path.join(data_dir, f"split_v{int(val_ratio*100)}_{int(test_ratio*100)}.npz")

# ----- 1) 设备 -----
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device:", device)

# ----- 2) 只需评估用的 transform -----
eval_tf = transforms.Compose([
    transforms.Resize((224, 224), interpolation=InterpolationMode.BICUBIC),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225]),
])

# ----- 3) 读取数据集 & 固定划分（与训练一致：读取 split_cache）-----
base_ds   = datasets.ImageFolder(data_dir)           # 仅用于拿 targets/classes
targets   = np.array(base_ds.targets)
classes   = base_ds.classes
n_classes = len(classes)
print("Classes (from dataset):", classes)

# === 新增：为“显示/报告”自定义类别名（不影响模型），若不是3类则回退为原始名称 ===
if n_classes == 3:
    display_names = ["Acer", "Betula", "Ulmus"]
else:
    display_names = classes
    print("[Note] 非3类数据集，display_names 将使用数据集原始类别名。")

if not os.path.exists(split_cache):
    raise FileNotFoundError(
        f"未找到划分缓存 {split_cache}。\n"
        "请先运行训练脚本（会生成 split_vXX_XX.npz），或者把该文件拷贝到相同路径。"
    )
npz = np.load(split_cache)
test_idx = npz["test"]

full_eval_ds = datasets.ImageFolder(data_dir, transform=eval_tf)
test_ds  = Subset(full_eval_ds, test_idx)
test_dl  = DataLoader(test_ds, batch_size=16, shuffle=False, num_workers=2, pin_memory=(device.type=='cuda'))
print(f"Test set size: {len(test_idx)}")

# ----- 4) 重建模型结构（与训练时一致）-----
try:
    model = models.resnet101(weights=models.ResNet101_Weights.DEFAULT)
except Exception as e:
    print("[Warning] 预训练权重下载失败，改用随机初始化（准确率会受影响）:", repr(e))
    model = models.resnet101(weights=None)

model.fc = nn.Linear(model.fc.in_features, n_classes)
model = model.to(device)

# ----- 5) 加载最佳权重 -----
if os.path.exists(ckpt_path):
    print("Loading checkpoint:", ckpt_path)
    state = torch.load(ckpt_path, map_location=device)
    model.load_state_dict(state, strict=True)
    print("Loaded best weights ✓")
else:
    print(f"[Warning] 未找到权重文件：{ckpt_path}\n将使用随机初始化的模型进行评估（仅用于流程检查）。")

# ----- 6) 测试集推理 -----
model.eval()
all_preds, all_labels = [], []
with torch.no_grad():
    for x, y in test_dl:
        out = model(x.to(device)).argmax(1).cpu()
        all_preds.append(out)
        all_labels.append(y)

y_true = torch.cat(all_labels).numpy() if all_labels else np.array([])
y_pred = torch.cat(all_preds).numpy()  if all_preds  else np.array([])

if y_true.size == 0:
    raise RuntimeError("测试集为空或 DataLoader 未正确构建。请检查 data_dir 与 split_cache。")

# ----- 7) 计算指标 -----
acc         = accuracy_score(y_true, y_pred)
macro_f1    = f1_score(y_true, y_pred, average='macro', zero_division=0)
weighted_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
bal_acc     = balanced_accuracy_score(y_true, y_pred)

print("\n=== Test Metrics ===")
print(f"Accuracy        : {acc*100:.2f}%")
print(f"Macro F1        : {macro_f1:.3f}")
print(f"Weighted F1     : {weighted_f1:.3f}")
print(f"Balanced Acc    : {bal_acc:.3f}")

# ----- 8) 分类报告（使用 display_names，避免手写错位）-----
print("\n=== Classification Report (Test) ===")
print(classification_report(y_true, y_pred, target_names=display_names, digits=3, zero_division=0))

# ----- 9) 混淆矩阵（放大坐标轴与数字；使用 display_names）-----
cm = confusion_matrix(y_true, y_pred)

# 字体大小参数（你可按需再调）
tick_fs   = 20   # 坐标轴刻度字体
label_fs  = 20   # 轴标题字体
title_fs  = 18   # 图题字体
number_fs = 26   # 格子内数字字体

fig, ax = plt.subplots(figsize=(7.5, 7.5))   # 画布也略放大，便于大字体显示
im = ax.imshow(cm, cmap=plt.cm.Blues)

# 坐标轴刻度与标签（使用自定义显示名），并整体增大字体
ax.set_xticks(np.arange(len(display_names)))
ax.set_xticklabels(display_names, rotation=30, ha='right', fontsize=tick_fs)
ax.set_yticks(np.arange(len(display_names)))
ax.set_yticklabels(display_names, fontsize=tick_fs)

ax.set_xlabel("Predicted label", fontsize=label_fs)
ax.set_ylabel("True label", fontsize=label_fs)
ax.set_title("Test Confusion Matrix (Counts)", fontsize=title_fs)

# 每个格子的数值，自动黑/白以对比底色
thresh = cm.max() / 2.0 if cm.size > 0 else 0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(
            j, i, str(cm[i, j]),
            ha='center', va='center',
            fontsize=number_fs,
            color='white' if cm[i, j] > thresh else 'black'
        )

ax.set_aspect('equal')   # 正方形格子
plt.tight_layout()
plt.show()
# Out:
# Device: cuda
# Classes (from dataset): ['Acer', 'Betula', 'Ulmaceae']
# Test set size: 440
# Loading checkpoint: /content/drive/MyDrive/my_dataset/Classification_uniform/best_model_val_macroF1.pt
# Loaded best weights ✓
#
# === Test Metrics ===
# Accuracy        : 95.91%
# Macro F1        : 0.956
# Weighted F1     : 0.959
# Balanced Acc    : 0.957
#
# === Classification Report (Test) ===
#               precision    recall  f1-score   support
#
#         Acer      0.932     0.941     0.937       102
#       Betula      0.965     0.965     0.965       141
#        Ulmus      0.969     0.964     0.967       197
#
#     accuracy                          0.959       440
#    macro avg      0.955     0.957     0.956       440
# weighted avg      0.959     0.959     0.959       440

# %% [markdown]
# # 统计分析

# %% [markdown]
# 换算比例尺

# %%
# 原始图像尺寸
import cv2

# 图像路径
img_path = "/content/drive/MyDrive/my_dataset/Acer_BM_3678_Acer_monospessulatum_grid_preview.png"

# 读取图像
img = cv2.imread(img_path)

if img is None:
    print("图像无法读取，请检查路径")
else:
    height, width = img.shape[:2]
    print(f"Image dimensions: width = {width} pixels, height = {height} pixels")
# Out:
# Image dimensions: width = 28191 pixels, height = 25963 pixels

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 设置参数
img_path = "/content/drive/MyDrive/my_dataset/Acer_BM_3678_Acer_monospessulatum_grid_preview.png"
real_length_um = 500  # 图像标注的比例尺实际长度（单位：μm）
crop_height = 4000   # 裁剪区域高度（像素）
crop_width = 4000   # 裁剪区域宽度（像素）

img = cv2.imread(img_path)
if img is None:
    raise FileNotFoundError("Image read failed")

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
h, w = gray.shape

# 裁剪右下角区域（包含比例尺线
roi = gray[h - crop_height : h, w - crop_width : w]

# 图像二值化（找出黑色线条）
_, binary = cv2.threshold(255 - roi, 200, 255, cv2.THRESH_BINARY)

# 查找轮廓
contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# 寻找最长的横线段
max_len = 0
scale_bar_length = None
for cnt in contours:
    x, y, w_box, h_box = cv2.boundingRect(cnt)
    if w_box > max_len and h_box < w_box * 0.3:  # 水平线
        max_len = w_box
        scale_bar_length = w_box

# 输出换算结果
if scale_bar_length:
    um_per_pixel = real_length_um / scale_bar_length
    print(f"Scale bar length: {scale_bar_length} pixel")
    print(f"Scale ratio: 1 pixel ≈ {um_per_pixel:.2f} μm")
else:
    print("Scale line segment not recognized")

# Region of Interest
plt.imshow(roi, cmap='gray')
plt.title("Cropped ROI (Bottom-Right)")
plt.axis("off")
plt.show()
# Out:
# Scale bar length: 3042 pixel
# Scale ratio: 1 pixel ≈ 0.16 μm

# %%
# Calculate μm/pixel of the original image
# μm_per_pixel_original = 500 / 3042 ≈ 0.1644 μm/pixel

# Calculate downsample scaling
# scale_factor = 3072 / 512

# Analyze images in μm/pixel
# μm_per_pixel_analysis = 0.1644 × 6 = 0.9864 μm/pixel

PIXEL_SIZE = 0.9864  # μm/pixel

# %% [markdown]
# Get the size of each pollen image

# %%
import os
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import re  # 用于提取 slide_id

# 输入路径（透明花粉图像）
base_dir = "/content/drive/MyDrive/my_dataset/MaskedTransparent"
species_list = ["Acer", "Betula", "Ulmaceae"]

results = []

# 遍历每个物种子文件夹
for species in species_list:
    folder = os.path.join(base_dir, species)
    if not os.path.isdir(folder):
        continue

    for fname in tqdm(os.listdir(folder), desc=f"Processing {species}"):
        if not fname.lower().endswith(".png"):
            continue
        path = os.path.join(folder, fname)

        # 读取透明图像（保留 alpha 通道）
        img = cv2.imread(path, cv2.IMREAD_UNCHANGED)
        if img is None or img.shape[2] != 4:
            continue

        # 提取 alpha 通道
        alpha = img[:, :, 3]
        area = int(np.sum(alpha > 0))

        # 提取 slide_id
        match_slide = re.search(r"(BM_\d+)", fname)
        slide_id = match_slide.group(1) if match_slide else "BM_xxxx"

        results.append({
            "filename": fname,
            "species": species,
            "area_pixels": area,
            "slide_id": slide_id
        })

# 保存为 CSV 文件
df = pd.DataFrame(results)
csv_path = "/content/drive/MyDrive/my_dataset/pollen_area_stats_with_slide.csv"
df.to_csv(csv_path, index=False)
print(f"Size data with slide ID saved: {csv_path}")
# Out:
# Processing Acer: 100%|██████████| 2056/2056 [00:26<00:00, 78.74it/s]
# Processing Betula: 100%|██████████| 4626/4626 [01:00<00:00, 76.57it/s]
# Processing Ulmaceae: 100%|██████████| 12259/12259 [02:50<00:00, 72.06it/s]
# Size data with slide ID saved: /content/drive/MyDrive/my_dataset/pollen_area_stats_with_slide.csv

# %% [markdown]
# 核密度估计曲线（KDE 图）

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# 读取数据
csv_path = "/content/drive/MyDrive/my_dataset/pollen_area_stats_with_slide.csv"
df = pd.read_csv(csv_path)

# 真实面积
PIXEL_SIZE = 0.9864  # μm/pixel
df["area_um2"] = df["area_pixels"] * (PIXEL_SIZE ** 2)

# 文件夹名 -> 学名
name_map = {
    "Acer": "Acer monspessulanum",
    "Betula": "Betula pendula",
    "Ulmaceae": "Ulmus hollandica"
}
df["species_label"] = df["species"].map(name_map)

# 想要的顺序（与学名一一对应）
hue_order = ["Acer monspessulanum", "Betula pendula", "Ulmus hollandica"]

# 生成配色并构建 palette 映射（确保线条与图例颜色一致）
palette_colors = sns.color_palette(n_colors=len(hue_order))
palette = {name: color for name, color in zip(hue_order, palette_colors)}

# 绘图
plt.figure(figsize=(12, 6))
ax = sns.kdeplot(
    data=df,
    x="area_um2",
    hue="species_label",
    hue_order=hue_order,
    palette=palette,
    fill=True,
    common_norm=False
)

# 固定横轴范围
plt.xlim(0, 2500)
plt.title("Pollen Size Distribution by Species")
plt.xlabel("Pollen Size (μm²)")
plt.ylabel("Density")

# 添加背景网格
ax.grid(True, which="both", linestyle="--", linewidth=0.5, alpha=0.7)

# 手动创建图例
legend_handles = [Patch(facecolor=palette[name], edgecolor='none', label=name) for name in hue_order]
ax.legend(handles=legend_handles, title="Species", loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# 柱状图

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 读取面积数据
csv_path = "/content/drive/MyDrive/my_dataset/pollen_area_stats_with_slide.csv"
df = pd.read_csv(csv_path)

# 添加真实单位列
PIXEL_SIZE = 0.9864  # μm/pixel
df["area_um2"] = df["area_pixels"] * (PIXEL_SIZE ** 2)

# 文件夹名 -> 学名
name_map = {
    "Acer": "Acer monspessulanum",
    "Betula": "Betula pendula",
    "Ulmaceae": "Ulmus hollandica"
}
df["species_label"] = df["species"].map(name_map)

# 提取物种
species_list = ["Acer monspessulanum", "Betula pendula", "Ulmus hollandica"]

# 颜色
colors = {
    "Acer monspessulanum": "steelblue",
    "Betula pendula": "orange",
    "Ulmus hollandica": "green"
}

# 设置 bin 范围
all_data = df["area_um2"].values
bin_width_um2 = 200
bin_edges = np.arange(0, 2500 + bin_width_um2, bin_width_um2)

# 绘图
plt.figure(figsize=(12, 6))

for species in species_list:
    data = df[df["species_label"] == species]["area_um2"].values
    plt.hist(data,
             bins=bin_edges,
             alpha=0.5,
             density=True,
             label=species,
             color=colors[species],
             edgecolor='black')

    # 添加均值线
    plt.axvline(data.mean(),
                color=colors[species],
                linestyle='--',
                linewidth=2,
                label=f"{species} Mean")

# 图表信息
plt.xlabel("Pollen Size (μm²)")
plt.ylabel("Density")
plt.title("Pollen Size Histogram by Species")
plt.xlim(0, 2500)   # 固定横坐标范围
plt.legend(title="Species")

# 添加背景网格
plt.grid(True, which="both", linestyle="--", linewidth=0.5, alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# major axis and minor axis

# %%
import os
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import re  # 用于提取 slide_id

# 设置路径和物种
base_dir = "/content/drive/MyDrive/my_dataset/MaskedTransparent"
species_list = ["Acer", "Betula", "Ulmaceae"]

results = []

for sp in species_list:
    sp_dir = os.path.join(base_dir, sp)

    for fname in tqdm(os.listdir(sp_dir), desc=f"Processing {sp}"):
        if not fname.lower().endswith(".png"):
            continue
        fpath = os.path.join(sp_dir, fname)

        img = cv2.imread(fpath, cv2.IMREAD_UNCHANGED)
        if img is None or img.shape[2] != 4:
            continue

        alpha = img[:, :, 3]
        mask = (alpha > 0).astype(np.uint8) * 255

        contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        if len(contours) == 0:
            continue

        cnt = max(contours, key=cv2.contourArea)
        if len(cnt) < 5:
            continue

        # 拟合椭圆
        ellipse = cv2.fitEllipse(cnt)
        (cx, cy), (major, minor), angle = ellipse
        area = cv2.contourArea(cnt)

        if area > 10000:  # 排除明显粘连或超大异常
            continue

        ratio = max(major, minor) / min(major, minor)
        if ratio > 4.0:  # 排除特别细长异常
            continue

        # 提取 slide_id
        match_slide = re.search(r"(BM_\d+)", fname)
        slide_id = match_slide.group(1) if match_slide else "BM_xxxx"

        results.append({
            "filename": fname,
            "species": sp,
            "major_axis": max(major, minor),
            "minor_axis": min(major, minor),
            "axis_ratio": ratio,
            "area": area,
            "slide_id": slide_id
        })

# 保存为 CSV
df = pd.DataFrame(results)
save_path = "/content/drive/MyDrive/my_dataset/pollen_ellipse_measurements_with_slide.csv"
df.to_csv(save_path, index=False)
print(f"Saved to {save_path}")
# Out:
# Processing Acer: 100%|██████████| 2056/2056 [00:42<00:00, 48.21it/s]
# Processing Betula: 100%|██████████| 4626/4626 [01:32<00:00, 50.22it/s]
# Processing Ulmaceae: 100%|██████████| 12259/12259 [05:33<00:00, 36.76it/s]
# Saved to /content/drive/MyDrive/my_dataset/pollen_ellipse_measurements_with_slide.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

save_path = "/content/drive/MyDrive/my_dataset/pollen_ellipse_measurements_with_slide.csv"
df = pd.read_csv(save_path)

# —— 单位换算 ——
df["major_um"] = df["major_axis"] * PIXEL_SIZE
df["minor_um"] = df["minor_axis"] * PIXEL_SIZE

# —— 物种名映射为学名 ——
name_map = {
    "Acer": "Acer monspessulanum",
    "Betula": "Betula pendula",
    "Ulmaceae": "Ulmus hollandica"
}
df["species_label"] = df["species"].map(name_map)

# 顺序 & 颜色
hue_order = ["Acer monspessulanum", "Betula pendula", "Ulmus hollandica"]
palette = {
    "Acer monspessulanum": "steelblue",
    "Betula pendula": "orange",
    "Ulmus hollandica": "green"
}

# —— KDE：major axis ——
plt.figure(figsize=(10, 5))
ax = sns.kdeplot(
    data=df,
    x="major_um",
    hue="species_label",
    hue_order=hue_order,
    palette=palette,
    fill=True,
    common_norm=False
)
plt.xlim(10, 70)
plt.title("Major Axis Distribution")
plt.xlabel("Major Axis Length (μm)")
plt.ylabel("Density")

# 添加背景网格
ax.grid(True, which="both", linestyle="--", linewidth=0.5, alpha=0.7)

# 手动 legend
handles = [Patch(facecolor=palette[name], label=name) for name in hue_order]
ax.legend(handles=handles, title="Species", loc="upper right")

plt.tight_layout()
plt.show()

# —— KDE：minor axis ——
plt.figure(figsize=(10, 5))
ax = sns.kdeplot(
    data=df,
    x="minor_um",
    hue="species_label",
    hue_order=hue_order,
    palette=palette,
    fill=True,
    common_norm=False
)
plt.xlim(10, 70)
plt.title("Minor Axis Distribution")
plt.xlabel("Minor Axis Length (μm)")
plt.ylabel("Density")

# 添加背景网格
ax.grid(True, which="both", linestyle="--", linewidth=0.5, alpha=0.7)

# 手动 legend
handles = [Patch(facecolor=palette[name], label=name) for name in hue_order]
ax.legend(handles=handles, title="Species", loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ellipticity

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# 读取测量数据
df = pd.read_csv("/content/drive/MyDrive/my_dataset/pollen_ellipse_measurements_with_slide.csv")

# 像素转微米
PIXEL_SIZE = 0.9864  # μm/pixel
df["major_um"] = df["major_axis"] * PIXEL_SIZE
df["minor_um"] = df["minor_axis"] * PIXEL_SIZE

# 椭圆性
df["ellipticity"] = 1 - df["minor_um"] / df["major_um"]

# 文件夹名 -> 学名映射
name_map = {
    "Acer": "Acer monspessulanum",
    "Betula": "Betula pendula",
    "Ulmaceae": "Ulmus hollandica",
}
df["species_label"] = df["species"].map(name_map)

# 调试：确认映射是否成功（需看到3个非NaN学名）
print("species unique:", df["species"].unique())
print("species_label unique:", df["species_label"].unique())

# 固定顺序与配色
hue_order = ["Acer monspessulanum", "Betula pendula", "Ulmus hollandica"]
palette = {
    "Acer monspessulanum": "steelblue",
    "Betula pendula": "orange",
    "Ulmus hollandica": "green",
}

# 绘图（关闭 seaborn 自带图例）
plt.figure(figsize=(10, 5))
ax = sns.histplot(
    data=df,
    x="ellipticity",
    hue="species_label",
    hue_order=hue_order,
    palette=palette,
    bins=30,
    multiple="dodge",   # 你也可以改成 "layer" 或 "stack"
    kde=True,
    legend=False        # 关键：禁用内置图例
)

plt.title("Ellipticity Distribution per Species")
plt.xlabel("Ellipticity")
plt.ylabel("Count")

# 添加背景网格
ax.grid(True, which="both", linestyle="--", linewidth=0.5, alpha=0.7)

# 手动构造图例
handles = [Patch(facecolor=palette[name], edgecolor="none", label=name) for name in hue_order]
ax.legend(handles=handles, title="Species", loc="upper right")

plt.tight_layout()
plt.show()
# Out:
# species unique: ['Acer' 'Betula' 'Ulmaceae']
# species_label unique: ['Acer monspessulanum' 'Betula pendula' 'Ulmus hollandica']

# %% [markdown]
# # To compare the morphological differences (e.g., area, major axis, minor axis, ellipticity) between Acer monspessulanum and Betula pendula in two different countries and explore the possible reasons.

# %% [markdown]
# 总表格

# %%
import pandas as pd

# 读取数据
area_path = "/content/drive/MyDrive/my_dataset/pollen_area_stats_with_slide.csv"
ellipse_path = "/content/drive/MyDrive/my_dataset/pollen_ellipse_measurements_with_slide.csv"
slide_info_path = "/content/drive/MyDrive/my_dataset/List_of_Slides.xlsx"

area_df = pd.read_csv(area_path)
ellipse_df = pd.read_csv(ellipse_path)
slide_df = pd.read_excel(slide_info_path)

# 合并面积和形态数据
merged_df = pd.merge(ellipse_df, area_df[["filename", "area_pixels"]], on="filename", how="left")

# 单位换算
PIXEL_SIZE = 0.9864
merged_df["major_um"] = merged_df["major_axis"] * PIXEL_SIZE
merged_df["minor_um"] = merged_df["minor_axis"] * PIXEL_SIZE
merged_df["area_um2"] = merged_df["area_pixels"] * (PIXEL_SIZE ** 2)

# 计算椭圆度
merged_df["ellipticity"] = 1 - merged_df["minor_um"] / merged_df["major_um"]

# 添加 country 信息
slide_df["slide_id"] = slide_df["specimen number"].apply(lambda x: str(x).replace(" ", "_").strip())
slide_df["country"] = slide_df["COUNTRY"].str.strip()
merged_df = pd.merge(merged_df, slide_df[["slide_id", "country"]], on="slide_id", how="left")

# 整理列顺序
final_df = merged_df[[
    "filename", "species", "slide_id", "country",
    "area_pixels", "area_um2",
    "major_axis", "minor_axis", "major_um", "minor_um",
    "axis_ratio", "ellipticity"
]]

# 保存为 Excel 文件
output_path = "/content/drive/MyDrive/my_dataset/morphology_summary.xlsx"
final_df.to_excel(output_path, index=False)
print(f"Saved successfully: {output_path}")
# Out:
# Saved successfully: /content/drive/MyDrive/my_dataset/morphology_summary.xlsx

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 读取花粉形态数据
df = pd.read_excel("/content/drive/MyDrive/my_dataset/morphology_summary.xlsx")

# 按物种筛选
acer_df = df[df["species"] == "Acer"]
betula_df = df[df["species"] == "Betula"]

# %% [markdown]
# Acer分布对比图

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# 定义国家顺序（legend 固定显示 France 和 Germany）
countries = ["France", "Germany"]

# pollen size
plt.figure(figsize=(8, 5))
ax = sns.kdeplot(
    data=acer_df,
    x="area_um2",
    hue="country",
    fill=True,
    common_norm=False,
    legend=False   # 关闭 seaborn 自带 legend
)
plt.title("Acer monspessulanum - Pollen Size")
plt.xlabel("Size (μm²)")
plt.xlim(0, 2500)
# 添加背景网格
ax.grid(True, which="both", linestyle="--", linewidth=0.5, alpha=0.7)
# 手动 legend（使用 seaborn 默认调色板）
default_colors = sns.color_palette(n_colors=len(countries))
handles = [Patch(facecolor=default_colors[i], label=countries[i]) for i in range(len(countries))]
ax.legend(handles=handles, title="Country", loc="upper right")
plt.tight_layout()
plt.show()

# major axis
plt.figure(figsize=(8, 5))
ax = sns.kdeplot(
    data=acer_df,
    x="major_um",
    hue="country",
    fill=True,
    common_norm=False,
    legend=False
)
plt.title("Acer monspessulanum - Major Axis")
plt.xlabel("Major Axis Length (μm)")
plt.xlim(20, 70)
# 添加背景网格
ax.grid(True, which="both", linestyle="--", linewidth=0.5, alpha=0.7)
# legend
handles = [Patch(facecolor=default_colors[i], label=countries[i]) for i in range(len(countries))]
ax.legend(handles=handles, title="Country", loc="upper right")
plt.tight_layout()
plt.show()

# ellipticity
plt.figure(figsize=(8, 5))
ax = sns.kdeplot(
    data=acer_df,
    x="ellipticity",
    hue="country",
    fill=True,
    common_norm=False,
    legend=False
)
plt.xlim(0, 0.6),
plt.title("Acer monspessulanum - Ellipticity")
plt.xlabel("Ellipticity")
# 添加背景网格
ax.grid(True, which="both", linestyle="--", linewidth=0.5, alpha=0.7)
# legend
handles = [Patch(facecolor=default_colors[i], label=countries[i]) for i in range(len(countries))]
ax.legend(handles=handles, title="Country", loc="upper right")
plt.tight_layout()
plt.show()

# %% [markdown]
# Betula分布对比图

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# 固定国家顺序
countries = ["England", "Sweden"]
# seaborn 默认调色板
default_colors = sns.color_palette(n_colors=len(countries))
handles = [Patch(facecolor=default_colors[i], label=countries[i]) for i in range(len(countries))]

# --- Pollen size ---
plt.figure(figsize=(8, 5))
ax = sns.kdeplot(
    data=betula_df,
    x="area_um2",
    hue="country",
    fill=True,
    common_norm=False,
    legend=False   # 禁用 seaborn 自动图例
)
plt.title("Betula pendula - Pollen Size")
plt.xlabel("Size (μm²)")
plt.xlim(0, 1500)
# 添加背景网格
ax.grid(True, which="both", linestyle="--", linewidth=0.5, alpha=0.7)
ax.legend(handles=handles, title="Country", loc="upper right")
plt.tight_layout()
plt.show()

# --- Major axis ---
plt.figure(figsize=(8, 5))
ax = sns.kdeplot(
    data=betula_df,
    x="major_um",
    hue="country",
    fill=True,
    common_norm=False,
    legend=False
)
plt.title("Betula pendula - Major Axis")
plt.xlabel("Major Axis Length (μm)")
plt.xlim(20, 50)
# 添加背景网格
ax.grid(True, which="both", linestyle="--", linewidth=0.5, alpha=0.7)
ax.legend(handles=handles, title="Country", loc="upper right")
plt.tight_layout()
plt.show()

# --- Ellipticity ---
plt.figure(figsize=(8, 5))
ax = sns.kdeplot(
    data=betula_df,
    x="ellipticity",
    hue="country",
    fill=True,
    common_norm=False,
    legend=False
)
plt.xlim(0, 0.6),
plt.title("Betula pendula - Ellipticity")
plt.xlabel("Ellipticity")
# 添加背景网格
ax.grid(True, which="both", linestyle="--", linewidth=0.5, alpha=0.7)
ax.legend(handles=handles, title="Country", loc="upper right")
plt.tight_layout()
plt.show()

# %% [markdown]
# KS检验

# %% [markdown]
# Null Hypothesis (H₀):
# The Acer pollen area in France and Germany follows the same distribution (no significant difference).
#
# Alternative Hypothesis (H₁):
# The Acer pollen area in France and Germany has a different distribution.

# %%
import pandas as pd
from scipy.stats import ks_2samp
import matplotlib.pyplot as plt
import seaborn as sns

# 读取数据
df = pd.read_excel("/content/drive/MyDrive/my_dataset/morphology_summary.xlsx")

# 显示特征名
feature_name_map = {
    "area_um2": "size",
    "major_um": "major",
    "ellipticity": "ellipticity"
}

# 横坐标标签带单位
xlabel_map = {
    "area_um2": "Pollen Size (µm²)",
    "major_um": "Major Axis Length (µm)",
    "ellipticity": "Ellipticity"
}

# KS 检验函数
def run_ks(species, country1, country2, feature):
    subset = df[df["species"] == species]
    data1 = subset[subset["country"] == country1][feature].dropna()
    data2 = subset[subset["country"] == country2][feature].dropna()

    if len(data1) < 2 or len(data2) < 2:
        return {
            "Species": species,
            "Feature": feature_name_map.get(feature, feature),
            "Country1": country1,
            "Country2": country2,
            "KS Statistic": None,
            "p-value": None,
            "Significant": "Too few data"
        }

    stat, p = ks_2samp(data1, data2)
    significant = "Yes" if p < 0.05 else "No"

    # 绘图显示
    plt.figure(figsize=(8, 4))
    ax = sns.kdeplot(data1, label=country1, fill=True)
    sns.kdeplot(data2, label=country2, fill=True)
    plt.xlabel(xlabel_map.get(feature, feature))
    plt.title(f"{species} {feature_name_map.get(feature, feature)}: {country1} vs {country2}")
    plt.legend()
    # 添加背景网格
    ax.grid(True, which="both", linestyle="--", linewidth=0.5, alpha=0.7)
    plt.tight_layout()
    plt.show()

    return {
        "Species": species,
        "Feature": feature_name_map.get(feature, feature),
        "Country1": country1,
        "Country2": country2,
        "KS Statistic": round(stat, 4),
        "p-value": f"{p:.2e}",
        "Significant": significant
    }

# 设置比较项目
comparisons = [
    ("Acer", "France", "Germany", "area_um2"),
    ("Acer", "France", "Germany", "major_um"),
    ("Acer", "France", "Germany", "ellipticity"),
    ("Betula", "England", "Sweden", "area_um2"),
    ("Betula", "England", "Sweden", "major_um"),
    ("Betula", "England", "Sweden", "ellipticity"),
]

# 执行检验
results = [run_ks(sp, c1, c2, feat) for sp, c1, c2, feat in comparisons]
ks_results_df = pd.DataFrame(results)

# 显示结果表
ks_results_df
# Out:
#   Species      Feature Country1 Country2  KS Statistic   p-value Significant
# 0    Acer         size   France  Germany        0.0910  3.82e-04         Yes
# 1    Acer        major   France  Germany        0.2358  1.87e-25         Yes
# 2    Acer  ellipticity   France  Germany        0.2871  1.15e-37         Yes
# 3  Betula         size  England   Sweden        0.2569  1.90e-67         Yes
# 4  Betula        major  England   Sweden        0.2170  4.30e-48         Yes
# 5  Betula  ellipticity  England   Sweden        0.1592  5.46e-26         Yes
